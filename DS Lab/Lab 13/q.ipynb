# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score 
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("./SteelPlateFaults-2class.csv")
df.head()
# Out:
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0       1325       1339      30207      30238           268           29
# 1          1         16      55572      55629           370           48
# 2       1323       1333      68445      68506           330           48
# 3       1324       1333      75642      75681           207           25
# 4       1324       1335      97132      97213           594           55
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           31              25809                     79
# 1           62              39293                     27
# 2           61              33449                     90
# 3           39              21354                     93
# 4           81              61608                     93
#
#    Maximum_of_Luminosity  ...  Edges_X_Index  Edges_Y_Index  \
# 0                    124  ...         0.4828         1.0000
# ...

# %%
df.describe()
# Out:
#          X_Minimum    X_Maximum     Y_Minimum     Y_Maximum   Pixels_Areas  \
# count  1119.000000  1119.000000  1.119000e+03  1.119000e+03    1119.000000
# mean    505.691689   575.336908  1.559346e+06  1.559417e+06    3032.825737
# std     516.588405   482.705270  1.736716e+06  1.736739e+06    6536.594600
# min       0.000000     4.000000  6.712000e+03  6.724000e+03       2.000000
# 25%      41.000000   194.000000  3.786385e+05  3.786720e+05     104.000000
# 50%     270.000000   340.000000  1.094338e+06  1.094348e+06     276.000000
# 75%     967.000000   990.500000  2.143707e+06  2.143718e+06    5292.000000
# max    1705.000000  1713.000000  1.241645e+07  1.241647e+07  152655.000000
#
#         X_Perimeter   Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# count   1119.000000   1119.000000       1.119000e+03            1119.000000
# mean     168.374441    118.453083       3.309396e+05              81.152815
# ...

# %%
print("Number of Tuples: " + str(len(df)))
# Out:
# Number of Tuples: 1119

# %%
# l = (int)(0.7*len(df))
# # train_data = df.iloc[:l]
# # test_data = df.iloc[l:]
# # print(l,len(train_data),len(test_data))

# %%
# train_data.head()
# test_data.head()

# %%
y = df['Class']
X = df.drop('Class', axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42,shuffle = True)
k_values = [1,3,5]

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    cm= confusion_matrix(y_test, y_pred)
    print ("Accuracy for k = " + str(k) + ": ", accuracy_score(y_test, y_pred))
    print(cm)
# Out:
# Accuracy for k = 1:  0.8392857142857143
# [[ 81  27]
#  [ 27 201]]
# Accuracy for k = 3:  0.8898809523809523
# [[ 83  25]
#  [ 12 216]]
# Accuracy for k = 5:  0.8958333333333334
# [[ 82  26]
#  [  9 219]]

# %%
min_max = MinMaxScaler()
N=min_max.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(N, y, test_size = 0.3, random_state = 42,shuffle = True)
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    cm= confusion_matrix(y_test, y_pred)
    print ("Accuracy for k = " + str(k) + ": ", accuracy_score(y_test, y_pred))
    print(cm)
# Out:
# Accuracy for k = 1:  0.9613095238095238
# [[104   4]
#  [  9 219]]
# Accuracy for k = 3:  0.9702380952380952
# [[104   4]
#  [  6 222]]
# Accuracy for k = 5:  0.9642857142857143
# [[103   5]
#  [  7 221]]
