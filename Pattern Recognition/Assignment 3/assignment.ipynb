# %% [markdown]
# # **CS20B1044 Pattern Recognition Assignment 3**

# %%
# This assignment is done by CS20B1044 Avinash R Changrani

# importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1. <b>Consider the 128- dimensional feature vectors (d=128) given in the “gender.csv” file. (2 classes, male and female)
#
#     a) Use PCA to reduce the dimension from d to d'. (Here d=128)
#
#     b) Display the eigenvalue based on increasing order, select the d' of the corresponding eigenvector which is the appropriate dimension d' ( select d' S.T first 95% of λ values of the covariance matrix are considered).
#
#     c) Use d' features to classify the test cases (use any classification algorithm taught in class like Bayes classifier, minimum distance classifier, and so on)</b>
#
#     **Dataset Specifications:**
#     Total number of samples = 800 \
#     Number of classes = 2 (labeled as “male” and “female”) \
#     Samples from “1 to 400” belongs to class “male” \
#     Samples from “401 to 800” belongs to class “female” \
#     Number of samples per class = 400 \
#     Number of dimensions = 128
#
#     **Use the following information to design classifier:**
#
#     Number of test cases (first 10 in each class) = 20 \
#     Number of training feature vectors ( remaining 390 in each class) = 390 \
#     Number of reduced dimensions = d' (map 128 to d' features vector)

# %%
# loading the gender.csv file into dataframe

df = pd.read_csv("./gender.csv")

df
# Out:
#      Unnamed: 0 Unnamed: 1         0         1         2         3         4  \
# 0             1       male -0.066420  0.151611  0.027740  0.052771 -0.066105
# 1             2       male -0.030614  0.049667  0.008084 -0.050324  0.007649
# 2             3       male -0.096178  0.061127  0.035326 -0.035388 -0.090728
# 3             4       male -0.103057  0.085044  0.078333 -0.035873 -0.028163
# 4             5       male -0.125815  0.120046  0.023131 -0.042901  0.038215
# ..          ...        ...       ...       ...       ...       ...       ...
# 795         796     female -0.164731  0.064301  0.058630 -0.017420 -0.157600
# 796         797     female -0.095308  0.051095  0.092913 -0.101745 -0.083153
# 797         798     female -0.202852  0.037039  0.079731 -0.047156 -0.140062
# 798         799     female -0.088300  0.063530  0.049627 -0.026011 -0.172773
# 799         800     female -0.156201  0.055165  0.142716 -0.115393 -0.128982
#
#             5         6         7  ...       118       119       120  \
# 0   -0.041232 -0.002637 -0.158467  ...  0.025989 -0.001087  0.027260
# 1   -0.063818 -0.019530 -0.119905  ...  0.044229 -0.023900 -0.028108
# 2   -0.018634 -0.024315 -0.139786  ...  0.111141  0.059436 -0.029222
# 3    0.004924  0.007829 -0.017016  ...  0.100793 -0.002644 -0.023388
# 4   -0.049677 -0.054258 -0.130758  ...  0.090197  0.067527  0.039926
# ..        ...       ...       ...  ...       ...       ...       ...
# 795 -0.022536  0.002864 -0.072739  ...  0.095115  0.007198 -0.004655
# 796 -0.028159  0.009090 -0.114513  ...  0.056078  0.119846  0.087470
# 797 -0.080246  0.057668 -0.122083  ...  0.066954  0.035684 -0.023112
# 798  0.086218  0.042710 -0.161852  ...  0.039460  0.067547  0.040426
# 799 -0.139830 -0.037305 -0.101402  ...  0.024955  0.066980 -0.002332
#
#           121       122       123       124       125       126       127
# 0   -0.046754 -0.118619 -0.163774 -0.000590 -0.076400  0.107497  0.001567
# 1    0.040618 -0.146579 -0.141244  0.016162  0.017638  0.080610 -0.015930
# 2    0.042115 -0.222173 -0.116908  0.093428  0.017391  0.057652  0.086116
# 3    0.029497 -0.139830 -0.119243  0.005306 -0.015100  0.161575  0.062462
# 4    0.047469 -0.056852 -0.076700  0.004966  0.028171  0.026041  0.084135
# ..        ...       ...       ...       ...       ...       ...       ...
# 795  0.023957 -0.170753 -0.136630  0.041614  0.031600  0.019064  0.004384
# 796  0.017481 -0.096594 -0.084553  0.037709  0.030732 -0.083713  0.064970
# 797 -0.030452 -0.154243 -0.188270  0.071086  0.037384 -0.006257  0.039977
# 798  0.028007 -0.154515 -0.127736  0.046967  0.009701 -0.016942  0.048071
# 799 -0.045738 -0.110557 -0.014995 -0.002124 -0.010298 -0.028856  0.075323
#
# [800 rows x 130 columns]

# %%
# drop Unnamed: 0 and Unnamed: 1 columns as class labels are not required for PCA

# get the class labels from the dataframe
labels = df['Unnamed: 1'].unique()

df_labels = df['Unnamed: 1']

df1 = df.drop(columns = ["Unnamed: 0"])

# rename the Unnamed: 1 column to class
df1.rename(columns = {"Unnamed: 1": "class"}, inplace = True)

# drop the class column
df = df.drop(columns = ["Unnamed: 0", "Unnamed: 1"])

df
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.066420  0.151611  0.027740  0.052771 -0.066105 -0.041232 -0.002637
# 1   -0.030614  0.049667  0.008084 -0.050324  0.007649 -0.063818 -0.019530
# 2   -0.096178  0.061127  0.035326 -0.035388 -0.090728 -0.018634 -0.024315
# 3   -0.103057  0.085044  0.078333 -0.035873 -0.028163  0.004924  0.007829
# 4   -0.125815  0.120046  0.023131 -0.042901  0.038215 -0.049677 -0.054258
# ..        ...       ...       ...       ...       ...       ...       ...
# 795 -0.164731  0.064301  0.058630 -0.017420 -0.157600 -0.022536  0.002864
# 796 -0.095308  0.051095  0.092913 -0.101745 -0.083153 -0.028159  0.009090
# 797 -0.202852  0.037039  0.079731 -0.047156 -0.140062 -0.080246  0.057668
# 798 -0.088300  0.063530  0.049627 -0.026011 -0.172773  0.086218  0.042710
# 799 -0.156201  0.055165  0.142716 -0.115393 -0.128982 -0.139830 -0.037305
#
#             7         8         9  ...       118       119       120  \
# 0   -0.158467  0.130467 -0.044872  ...  0.025989 -0.001087  0.027260
# 1   -0.119905  0.186553 -0.044821  ...  0.044229 -0.023900 -0.028108
# 2   -0.139786  0.052211 -0.052085  ...  0.111141  0.059436 -0.029222
# 3   -0.017016  0.114907 -0.056267  ...  0.100793 -0.002644 -0.023388
# 4   -0.130758  0.173457 -0.011889  ...  0.090197  0.067527  0.039926
# ..        ...       ...       ...  ...       ...       ...       ...
# 795 -0.072739  0.030554 -0.121480  ...  0.095115  0.007198 -0.004655
# 796 -0.114513  0.157421 -0.069665  ...  0.056078  0.119846  0.087470
# 797 -0.122083  0.165443 -0.104478  ...  0.066954  0.035684 -0.023112
# 798 -0.161852  0.185083 -0.162894  ...  0.039460  0.067547  0.040426
# 799 -0.101402  0.048473 -0.041618  ...  0.024955  0.066980 -0.002332
#
#           121       122       123       124       125       126       127
# 0   -0.046754 -0.118619 -0.163774 -0.000590 -0.076400  0.107497  0.001567
# 1    0.040618 -0.146579 -0.141244  0.016162  0.017638  0.080610 -0.015930
# 2    0.042115 -0.222173 -0.116908  0.093428  0.017391  0.057652  0.086116
# 3    0.029497 -0.139830 -0.119243  0.005306 -0.015100  0.161575  0.062462
# 4    0.047469 -0.056852 -0.076700  0.004966  0.028171  0.026041  0.084135
# ..        ...       ...       ...       ...       ...       ...       ...
# 795  0.023957 -0.170753 -0.136630  0.041614  0.031600  0.019064  0.004384
# 796  0.017481 -0.096594 -0.084553  0.037709  0.030732 -0.083713  0.064970
# 797 -0.030452 -0.154243 -0.188270  0.071086  0.037384 -0.006257  0.039977
# 798  0.028007 -0.154515 -0.127736  0.046967  0.009701 -0.016942  0.048071
# 799 -0.045738 -0.110557 -0.014995 -0.002124 -0.010298 -0.028856  0.075323
#
# [800 rows x 128 columns]

# %%
df1
# Out:
#       class         0         1         2         3         4         5  \
# 0      male -0.066420  0.151611  0.027740  0.052771 -0.066105 -0.041232
# 1      male -0.030614  0.049667  0.008084 -0.050324  0.007649 -0.063818
# 2      male -0.096178  0.061127  0.035326 -0.035388 -0.090728 -0.018634
# 3      male -0.103057  0.085044  0.078333 -0.035873 -0.028163  0.004924
# 4      male -0.125815  0.120046  0.023131 -0.042901  0.038215 -0.049677
# ..      ...       ...       ...       ...       ...       ...       ...
# 795  female -0.164731  0.064301  0.058630 -0.017420 -0.157600 -0.022536
# 796  female -0.095308  0.051095  0.092913 -0.101745 -0.083153 -0.028159
# 797  female -0.202852  0.037039  0.079731 -0.047156 -0.140062 -0.080246
# 798  female -0.088300  0.063530  0.049627 -0.026011 -0.172773  0.086218
# 799  female -0.156201  0.055165  0.142716 -0.115393 -0.128982 -0.139830
#
#             6         7         8  ...       118       119       120  \
# 0   -0.002637 -0.158467  0.130467  ...  0.025989 -0.001087  0.027260
# 1   -0.019530 -0.119905  0.186553  ...  0.044229 -0.023900 -0.028108
# 2   -0.024315 -0.139786  0.052211  ...  0.111141  0.059436 -0.029222
# 3    0.007829 -0.017016  0.114907  ...  0.100793 -0.002644 -0.023388
# 4   -0.054258 -0.130758  0.173457  ...  0.090197  0.067527  0.039926
# ..        ...       ...       ...  ...       ...       ...       ...
# 795  0.002864 -0.072739  0.030554  ...  0.095115  0.007198 -0.004655
# 796  0.009090 -0.114513  0.157421  ...  0.056078  0.119846  0.087470
# 797  0.057668 -0.122083  0.165443  ...  0.066954  0.035684 -0.023112
# 798  0.042710 -0.161852  0.185083  ...  0.039460  0.067547  0.040426
# 799 -0.037305 -0.101402  0.048473  ...  0.024955  0.066980 -0.002332
#
#           121       122       123       124       125       126       127
# 0   -0.046754 -0.118619 -0.163774 -0.000590 -0.076400  0.107497  0.001567
# 1    0.040618 -0.146579 -0.141244  0.016162  0.017638  0.080610 -0.015930
# 2    0.042115 -0.222173 -0.116908  0.093428  0.017391  0.057652  0.086116
# 3    0.029497 -0.139830 -0.119243  0.005306 -0.015100  0.161575  0.062462
# 4    0.047469 -0.056852 -0.076700  0.004966  0.028171  0.026041  0.084135
# ..        ...       ...       ...       ...       ...       ...       ...
# 795  0.023957 -0.170753 -0.136630  0.041614  0.031600  0.019064  0.004384
# 796  0.017481 -0.096594 -0.084553  0.037709  0.030732 -0.083713  0.064970
# 797 -0.030452 -0.154243 -0.188270  0.071086  0.037384 -0.006257  0.039977
# 798  0.028007 -0.154515 -0.127736  0.046967  0.009701 -0.016942  0.048071
# 799 -0.045738 -0.110557 -0.014995 -0.002124 -0.010298 -0.028856  0.075323
#
# [800 rows x 129 columns]

# %%
print(df.shape)
# Out:
# (800, 128)

# %%
# splitting the data into training and testing data with first 10 of each class as training data and rest as testing data

# splitting the dataframe df1 into 2 based on class labels
df_male = df1[df1['class'] == 'male']

df_female = df1[df1['class'] == 'female']

# taking 1st 10 from each class as testing data
df_test = pd.concat([df_male.iloc[0:10], df_female.iloc[0:10]])

df_test_labels = df_test['class']

df_test = df_test.drop(columns = ["class"])

# taking rest of the data as training data
df_train = pd.concat([df_male.iloc[10:], df_female.iloc[10:]])

df_train_labels = df_train['class']

df_train = df_train.drop(columns = ["class"])

# %% [markdown]
# ## PCA using Inbuilt Function

# %%
# PCA using inbuilt function in sklearn to capture 95% of variance

from sklearn.decomposition import PCA

pca = PCA(n_components = 0.95)

pca.fit(df)

pca.n_components_
# Out:
# 57

# %%
# classify the test data using the training data after PCA

# transform the training data
df_train_pca = pca.transform(df_train)

# transform the testing data
df_test_pca = pca.transform(df_test)

# classify the testing data using Nearest Neighbor Classifier and print the accuracy 

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 1)

knn.fit(df_train_pca, df_train_labels)

pred = knn.predict(df_test_pca)

from sklearn.metrics import accuracy_score

print("Accuracy of the model using Nearest Neighbor is: ", accuracy_score(df_test_labels, pred)*100, "%")

# classify the test data using Naive Bayes Classifier and print the accuracy

from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(df_train_pca, df_train_labels)

pred = gnb.predict(df_test_pca)

print("Accuracy of the model using Naive Bayes is: ", accuracy_score(df_test_labels, pred)*100, "%")
# Out:
# Accuracy of the model using Nearest Neighbor is:  85.0 %
# Accuracy of the model using Naive Bayes is:  85.0 %

# %% [markdown]
# ## **PCA Without using Inbuilt Function**

# %%
# class PCA is defined to perform PCA on the data without using inbuilt functions and to capture 95% of variance

class PCA_inbuilt:
    def __init__(self, n_components = 0.95):
        self.n_components = n_components
        self.components = None
        self.mean = None
        self.variance = None
        self.explained_variance = None
        
    def fit(self, X):
        # mean of the data
        self.mean = np.mean(X, axis = 0)
        # subtract the mean from the data to make it mean centered
        X = X - self.mean
        # calculate the covariance matrix
        cov = np.cov(X.T)
        # calculate the eigen values and eigen vectors
        eigen_values, eigen_vectors = np.linalg.eig(cov)
        eigen_values, eigen_vectors = eigen_values.real, eigen_vectors.real
        eigen_pairs = [(np.abs(eigen_values[i]), eigen_vectors[:, i]) for i in range(len(eigen_values))]
        eigen_pairs.sort(key = lambda x: x[0], reverse = True)
        self.variance = sum(eigen_values)

        # calculate the variance captured by each component
        self.explained_variance = [eigen_pairs[i][0]/self.variance for i in range(len(eigen_pairs))]
        for i in range(len(eigen_pairs)):
            print("Variance captured by component", i+1, "is", eigen_pairs[i][0]/self.variance)

        # calculate the number of components required to capture 95% of variance
        cum_sum = 0
        for i in range(len(eigen_pairs)):
            cum_sum += eigen_pairs[i][0]
            if cum_sum/self.variance >= self.n_components:
                self.n_components = i + 1
                break
        self.components = np.array([eigen_pairs[i][1] for i in range(self.n_components)])

    # function to plot the variance vs number of components
    def plot_variance(self):
        plt.plot(np.cumsum(self.explained_variance))
        plt.xlabel("Number of principal components")
        plt.ylabel("Cumulative explained variance")
        plt.show()
        
    # function to transform the data
    def transform(self, X):
        X = X - self.mean
        return np.dot(X, self.components.T)

# %%
# PCA is performed on the data without using inbuilt functions and to capture 95% of variance
pca = PCA_inbuilt()

pca.fit(df)

print("Number of components required to capture 95% of variance is: ", pca.n_components)
# Out:
# Variance captured by component 1 is 0.12353020649086623
# Variance captured by component 2 is 0.07196408026147107
# Variance captured by component 3 is 0.051282492175501376
# Variance captured by component 4 is 0.04346508174041755
# Variance captured by component 5 is 0.03800638217885629
# Variance captured by component 6 is 0.035644040558097764
# Variance captured by component 7 is 0.03031279399301973
# Variance captured by component 8 is 0.027102073563969233
# Variance captured by component 9 is 0.02540400747925949
# Variance captured by component 10 is 0.02374418812235834
# Variance captured by component 11 is 0.02267915231760869
# Variance captured by component 12 is 0.021374539295361185
# Variance captured by component 13 is 0.020257448389925374
# Variance captured by component 14 is 0.019415589946185727
# Variance captured by component 15 is 0.01892082368412164
# Variance captured by component 16 is 0.017327675033688466
# Variance captured by component 17 is 0.016605251530297765
# Variance captured by component 18 is 0.01643122760481661
# Variance captured by component 19 is 0.015778406798700646
# Variance captured by component 20 is 0.015095446998958283
# Variance captured by component 21 is 0.014353718881855977
# Variance captured by component 22 is 0.013570815663075157
# Variance captured by component 23 is 0.013421474661626548
# Variance captured by component 24 is 0.012666596421130938
# Variance captured by component 25 is 0.012624734597798363
# Variance captured by component 26 is 0.011899679084533784
# Variance captured by component 27 is 0.011486077349723633
# Variance captured by component 28 is 0.010974739275980989
# Variance captured by component 29 is 0.010352312176236554
# Variance captured by component 30 is 0.010081431209069763
# Variance captured by component 31 is 0.00964397974612579
# Variance captured by component 32 is 0.00912782454907942
# Variance captured by component 33 is 0.009044075459288151
# Variance captured by component 34 is 0.008561653956580423
# Variance captured by component 35 is 0.008377801701791617
# Variance captured by component 36 is 0.008098932793127707
# Variance captured by component 37 is 0.007902754237884564
# Variance captured by component 38 is 0.007653518478277055
# Variance captured by component 39 is 0.0075732248974273875
# Variance captured by component 40 is 0.00725672228765859
# Variance captured by component 41 is 0.007104367938118546
# Variance captured by component 42 is 0.0068881799616469135
# Variance captured by component 43 is 0.0068187893764911425
# Variance captured by component 44 is 0.006430279448143076
# Variance captured by component 45 is 0.006163495604537052
# Variance captured by component 46 is 0.005974333921168655
# Variance captured by component 47 is 0.005738521573805052
# Variance captured by component 48 is 0.005526523175502608
# Variance captured by component 49 is 0.005504664289974289
# Variance captured by component 50 is 0.005297132106672506
# Variance captured by component 51 is 0.004914574034405888
# Variance captured by component 52 is 0.004787154410759385
# Variance captured by component 53 is 0.004608023730343702
# Variance captured by component 54 is 0.004405702058041699
# Variance captured by component 55 is 0.0042768467735916455
# Variance captured by component 56 is 0.004093003676851337
# Variance captured by component 57 is 0.0039009371209277957
# Variance captured by component 58 is 0.0036533093306075587
# Variance captured by component 59 is 0.003529987328371116
# Variance captured by component 60 is 0.003503474912337695
# Variance captured by component 61 is 0.003351024470319137
# Variance captured by component 62 is 0.003173448591619634
# Variance captured by component 63 is 0.0030124693559542247
# Variance captured by component 64 is 0.0029663153317056093
# Variance captured by component 65 is 0.00283162872529943
# Variance captured by component 66 is 0.002702745628131515
# Variance captured by component 67 is 0.0025719249133037514
# Variance captured by component 68 is 0.002522388082591332
# Variance captured by component 69 is 0.002277326101762683
# Variance captured by component 70 is 0.0021727501586341117
# Variance captured by component 71 is 0.002139478560024852
# Variance captured by component 72 is 0.0019370656609539658
# Variance captured by component 73 is 0.0017495352915457112
# Variance captured by component 74 is 0.0017192028962605712
# Variance captured by component 75 is 0.0011591078323274107
# Variance captured by component 76 is 0.0010398471453274762
# Variance captured by component 77 is 0.00052386752384721
# Variance captured by component 78 is 1.3770571773520412e-05
# Variance captured by component 79 is 2.576049421078054e-06
# Variance captured by component 80 is 9.270195014147289e-07
# Variance captured by component 81 is 2.8965105124835753e-07
# Variance captured by component 82 is 2.7426420206384744e-08
# Variance captured by component 83 is 3.745095791784234e-09
# Variance captured by component 84 is 1.6417211159448807e-09
# Variance captured by component 85 is 8.477755056183579e-10
# Variance captured by component 86 is 2.8641290101666044e-10
# Variance captured by component 87 is 7.217591848054334e-11
# Variance captured by component 88 is 2.7927685276659906e-11
# Variance captured by component 89 is 1.2567961770729117e-11
# Variance captured by component 90 is 7.665288599309515e-12
# Variance captured by component 91 is 2.325873658525193e-12
# Variance captured by component 92 is 2.053745909235772e-12
# Variance captured by component 93 is 9.088583474801928e-13
# Variance captured by component 94 is 4.804390818687801e-13
# Variance captured by component 95 is 2.417571926350918e-13
# Variance captured by component 96 is 1.6506279225751861e-13
# Variance captured by component 97 is 1.293291250026338e-13
# Variance captured by component 98 is 9.326374789977856e-14
# Variance captured by component 99 is 6.088083487487198e-14
# Variance captured by component 100 is 3.4632955795968717e-14
# Variance captured by component 101 is 3.198386440101255e-14
# Variance captured by component 102 is 2.4248003382753384e-14
# Variance captured by component 103 is 2.105961985661874e-14
# Variance captured by component 104 is 2.0106652539307142e-14
# Variance captured by component 105 is 1.9075069677249283e-14
# Variance captured by component 106 is 1.7073675863543703e-14
# Variance captured by component 107 is 1.62527022666179e-14
# Variance captured by component 108 is 1.5323495815816232e-14
# Variance captured by component 109 is 1.478373359630726e-14
# Variance captured by component 110 is 1.384770191438892e-14
# Variance captured by component 111 is 1.3295631050796325e-14
# Variance captured by component 112 is 1.247429065783461e-14
# Variance captured by component 113 is 1.1325232731398317e-14
# Variance captured by component 114 is 1.1155306117480264e-14
# Variance captured by component 115 is 9.748436622746314e-15
# Variance captured by component 116 is 8.892168373565705e-15
# Variance captured by component 117 is 8.57994019967784e-15
# Variance captured by component 118 is 8.116421207326789e-15
# Variance captured by component 119 is 7.98600115116721e-15
# Variance captured by component 120 is 7.582124415013905e-15
# Variance captured by component 121 is 7.0039825712873076e-15
# Variance captured by component 122 is 6.476592257494082e-15
# Variance captured by component 123 is 6.105665288767387e-15
# Variance captured by component 124 is 5.764847578153172e-15
# Variance captured by component 125 is 5.3176392593157644e-15
# Variance captured by component 126 is 4.78678885725576e-15
# Variance captured by component 127 is 4.142105330862444e-15
# Variance captured by component 128 is 3.43205081479925e-15
# Number of components required to capture 95% of variance is:  57

# %%
# transform the training data
df_train_pca = pca.transform(df_train)

# transform the testing data
df_test_pca = pca.transform(df_test)

# classify the testing data using Nearest Neighbor Classifier (neighbors=1 is Minimum Distance classifier) and print the accuracy
knn = KNeighborsClassifier(n_neighbors = 1)

knn.fit(df_train_pca, df_train_labels)

pred_mindist_pca = knn.predict(df_test_pca)

print("Accuracy of the model using Nearest Neighbor is: ", accuracy_score(df_test_labels, pred)*100, "%")

# classify the test data using Naive Bayes Classifier and print the accuracy
gnb = GaussianNB()

gnb.fit(df_train_pca, df_train_labels)

pred_nb_pca = gnb.predict(df_test_pca)

print("Accuracy of the model using Naive Bayes is: ", accuracy_score(df_test_labels, pred)*100, "%")
# Out:
# Accuracy of the model using Nearest Neighbor is:  85.0 %
# Accuracy of the model using Naive Bayes is:  85.0 %

# %%
# plot the variance vs number of components
pca.plot_variance()

# %% [markdown]
# 2. <b> For the same dataset “gender.csv” (2 classes, male and female)
#
#     a) Use LDA to reduce the dimension from d to d'. (Here d=128) \
#     b) Choose the direction 'W' to reduce the dimension d' (select appropriate d'). \
#     c) Use d' features to classify the test cases (use any classification algorithm will do, Bayes classifier, minimum distance classifier, and so on). </b>

# %% [markdown]
# ## LDA using Inbuilt Function

# %%
# perform LDA on the training data using inbuilt function in sklearn

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components = 1)

lda.fit(df, df_labels)

# transform the training data   
df_train_lda = lda.transform(df_train)

# transform the testing data
df_test_lda = lda.transform(df_test)

# classify the testing data using Nearest Neighbor Classifier and print the accuracy
knn = KNeighborsClassifier(n_neighbors = 1)

knn.fit(df_train_lda, df_train_labels)

pred = knn.predict(df_test_lda)

print("Accuracy of the Nearest Neighbor model is: ", accuracy_score(df_test_labels, pred)*100, "%")

# classify the testing data using Naive Bayes Classifier and print the accuracy
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(df_train_lda, df_train_labels)

pred = gnb.predict(df_test_lda)

print("Accuracy of the Naive Bayes model is: ", accuracy_score(df_test_labels, pred)*100, "%")
# Out:
# Accuracy of the Nearest Neighbor model is:  85.0 %
# Accuracy of the Naive Bayes model is:  90.0 %

# %% [markdown]
# ## **LDA wtihout using Inbuilt Function**

# %%
# class LDA is defined to perform LDA on the data without using inbuilt functions and to capture 95% of variance
class LDA_inbuilt:
    # constructor to initialize the Class
    def __init__(self, n_components = 1):
        self.n_components = n_components
        self.components = None
        self.mean = None
        self.variance = None
        self.explained_variance = None
        
    # function to fit the data using scatter matrix sw and sb
    # Within class scatter matrix:
    # SW = sum((X_c - mean_X_c)^2 )
    # Between class scatter matrix:
    # SB = sum( n_c * (mean_X_c - mean_overall)^2 )
    def fit(self, X, y):
        # number of features
        self.n_features = X.shape[1]
        # overall mean
        self.mean = np.mean(X, axis = 0).values.reshape(self.n_features, 1)
        labels = np.unique(y)
        # initialize the scatter matrices
        sw = np.zeros((self.n_features, self.n_features))
        sb = np.zeros((self.n_features, self.n_features))

        # calculate the scatter matrices
        for c in labels:
            X_c = X[y == c]
            X_c = np.array(X_c)
            mean_c = np.array(np.mean(X_c, axis = 0))
            mean_c = mean_c.reshape(self.n_features, 1)
            # calculate the scatter matrix for each class
            for i in range(X_c.shape[0]):
                sw += (X_c[i].reshape(self.n_features, 1) - mean_c).dot((X_c[i].reshape(self.n_features, 1) - mean_c).T)
            #sw += np.dot((X_c - mean_c).T, (X_c - mean_c))
            # calculate the scatter matrix for all classes
            n_c = X_c.shape[0]
            #print(n_c * (mean_c - self.mean).dot((mean_c - self.mean).T))
            sb += n_c * (mean_c - self.mean).dot((mean_c - self.mean).T)

        #print("Scatter matrix SW is: ", sw)
        #print("Scatter matrix SB is: ", sb)
        # calculate the eigen values and eigen vectors of the scatter matrices
        eigen_values, eigen_vectors = np.linalg.eig(np.dot(np.linalg.inv(sw), sb))

        #print("Eigen values are: ", eigen_values)

        # sort the eigen values in descending order
        eigen_pairs = [(np.abs(eigen_values[i]), eigen_vectors[:, i]) for i in range(len(eigen_values))]
        eigen_pairs = sorted(eigen_pairs, key = lambda k: k[0], reverse = True)

        # calculate the number of components required to capture 95% of variance
        self.variance = sum(eigen_values)

        # print the explained variance for each eigen value
        self.explained_variance = [np.real(i/self.variance) for i in sorted(eigen_values, reverse = True)]
        # for i in range(len(self.explained_variance)):
        #     print("Explained variance for eigen value", i+1, "is: ", self.explained_variance[i])

        cum_sum = 0
        for i in range(len(self.explained_variance)):
            cum_sum += self.explained_variance[i]
            if cum_sum/self.variance >= 0.95: 
                self.n_components = i + 1
                break

        # store the eigen vectors corresponding to the eigen values in descending order
        self.components = np.real(np.array([eigen_pairs[i][1] for i in range(self.n_components)]))

    # function to plot the variance vs number of components
    def plot_variance(self):
        plt.plot(np.cumsum(self.explained_variance))
        plt.xlabel("Number of components")
        plt.ylabel("Cumulative explained variance")
        plt.show()
        
    def transform(self, X):
        # X = X - self.mean
        return np.dot(X, self.components.T)

# %%
# perform LDA on the training data using the LDA class defined above

lda = LDA_inbuilt()

lda.fit(df, df_labels)

# transform the training data
df_train_lda = lda.transform(df_train)

# transform the testing data
df_test_lda = lda.transform(df_test)

# classify the testing data using Nearest Neighbor Classifier and print the accuracy
knn = KNeighborsClassifier(n_neighbors = 1)

knn.fit(df_train_lda, df_train_labels)

pred_mindist_lda = knn.predict(df_test_lda)

print("Accuracy of the Nearest Neighbor model is: ", accuracy_score(df_test_labels, pred_mindist_lda)*100, "%")

# classify the testing data using Naive Bayes Classifier and print the accuracy
gnb = GaussianNB()

gnb.fit(df_train_lda, df_train_labels)

pred_nb_lda = gnb.predict(df_test_lda)

print("Accuracy of the Naive Bayes model is: ", accuracy_score(df_test_labels, pred_nb_lda)*100, "%")
# Out:
# Accuracy of the Nearest Neighbor model is:  90.0 %
# Accuracy of the Naive Bayes model is:  90.0 %

# %%
# plot the variance vs number of components
lda.plot_variance()

# %% [markdown]
# 3. **Give the comparative study for the above results w.r.t to classification accuracy in terms of the confusion matrix.**

# %%
# compare the accuracy of the models using PCA and LDA using confusion matrix and classification report

from sklearn.metrics import confusion_matrix, classification_report

# confusion matrix for the Nearest Neighbor model using PCA
print("Confusion Matrix for the Nearest Neighbor model using PCA is: ")
print(confusion_matrix(df_test_labels, pred_mindist_pca))

# classification report for the Naive Bayes model using PCA
print("Classification Report for the Nearest Neighbor model using PCA is: ")
print(classification_report(df_test_labels, pred_mindist_pca))

# confusion matrix for the Nearest Neighbor model using LDA
print("Confusion Matrix for the Nearest Neighbor model using LDA is: ")
print(confusion_matrix(df_test_labels, pred_mindist_lda))

# classification report for the Naive Bayes model using LDA
print("Classification Report for the Nearest Neighbor model using LDA is: ")
print(classification_report(df_test_labels, pred_mindist_lda))
# Out:
# Confusion Matrix for the Nearest Neighbor model using PCA is:
# [[8 2]
#  [1 9]]
# Classification Report for the Nearest Neighbor model using PCA is:
#               precision    recall  f1-score   support
#
#       female       0.89      0.80      0.84        10
#         male       0.82      0.90      0.86        10
#
#     accuracy                           0.85        20
#    macro avg       0.85      0.85      0.85        20
# weighted avg       0.85      0.85      0.85        20
#
# Confusion Matrix for the Nearest Neighbor model using LDA is:
# [[ 8  2]
#  [ 0 10]]
# Classification Report for the Nearest Neighbor model using LDA is:
#               precision    recall  f1-score   support
#
#       female       1.00      0.80      0.89        10
#         male       0.83      1.00      0.91        10
#
#     accuracy                           0.90        20
#    macro avg       0.92      0.90      0.90        20
# weighted avg       0.92      0.90      0.90        20

# %%
# confusion matrix for the Naive Bayes model using PCA
print("Confusion Matrix for the Naive Bayes model using PCA is: ")
print(confusion_matrix(df_test_labels, pred_nb_pca))

# classification report for the Naive Bayes model using PCA
print("Classification Report for the Naive Bayes model using PCA is: ")
print(classification_report(df_test_labels, pred_nb_pca))

# confusion matrix for the Naive Bayes model using LDA
print("Confusion Matrix for the Naive Bayes model using LDA is: ")
print(confusion_matrix(df_test_labels, pred_nb_lda))

# classification report for the Naive Bayes model using LDA
print("Classification Report for the Naive Bayes model using LDA is: ")
print(classification_report(df_test_labels, pred_nb_lda))
# Out:
# Confusion Matrix for the Naive Bayes model using PCA is:
# [[8 2]
#  [1 9]]
# Classification Report for the Naive Bayes model using PCA is:
#               precision    recall  f1-score   support
#
#       female       0.89      0.80      0.84        10
#         male       0.82      0.90      0.86        10
#
#     accuracy                           0.85        20
#    macro avg       0.85      0.85      0.85        20
# weighted avg       0.85      0.85      0.85        20
#
# Confusion Matrix for the Naive Bayes model using LDA is:
# [[ 8  2]
#  [ 0 10]]
# Classification Report for the Naive Bayes model using LDA is:
#               precision    recall  f1-score   support
#
#       female       1.00      0.80      0.89        10
#         male       0.83      1.00      0.91        10
#
#     accuracy                           0.90        20
#    macro avg       0.92      0.90      0.90        20
# weighted avg       0.92      0.90      0.90        20

# %%
# compare the accuracy of the models using PCA and LDA using a plot
# plot the accuracy of the models using PCA and LDA
models = ['Nearest Neighbor', 'Naive Bayes']
pca = [accuracy_score(df_test_labels, pred_mindist_pca)*100, accuracy_score(df_test_labels, pred_nb_pca)*100]
lda = [accuracy_score(df_test_labels, pred_mindist_lda)*100, accuracy_score(df_test_labels, pred_nb_lda)*100]

x = np.arange(len(models))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, pca, width, label='PCA')
rects2 = ax.bar(x + width/2, lda, width, label='LDA')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy of the models using PCA and LDA')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# 4. <b>Eigenfaces-Face classification using PCA (40 classes)
#
#     a) Use the following “face.csv” file to classify the faces of 40 different people using PCA. \
#     b) Do not use the in-built function for implementing PCA. \
#     c) Use appropriate classifier taught in class (use any classification algorithm taught in class like Bayes classifier, minimum distance classifier, and so on ) \
#     d) Refer to the following link for a description of the dataset: </b>
#     [link](https://towardsdatascience.com/eigenfaces-face-classification-in-python-7b8d2af3d3ea)

# %%
data = pd.read_csv("./face.csv")

data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.309917  0.367769  0.417355  0.442149  0.528926  0.607438  0.657025
# 1  0.454545  0.471074  0.512397  0.557851  0.595041  0.640496  0.681818
# 2  0.318182  0.400826  0.491736  0.528926  0.586777  0.657025  0.681818
# 3  0.198347  0.194215  0.194215  0.194215  0.190083  0.190083  0.243802
# 4  0.500000  0.545455  0.582645  0.623967  0.648760  0.690083  0.694215
#
#           7         8         9  ...      4087      4088      4089      4090  \
# 0  0.677686  0.690083  0.685950  ...  0.669422  0.652893  0.661157  0.475207
# 1  0.702479  0.710744  0.702479  ...  0.157025  0.136364  0.148760  0.152893
# 2  0.685950  0.702479  0.698347  ...  0.132231  0.181818  0.136364  0.128099
# 3  0.404959  0.483471  0.516529  ...  0.636364  0.657025  0.685950  0.727273
# 4  0.714876  0.723140  0.731405  ...  0.161157  0.177686  0.173554  0.177686
#
#        4091      4092      4093      4094      4095  target
# 0  0.132231  0.148760  0.152893  0.161157  0.157025       0
# 1  0.152893  0.152893  0.152893  0.152893  0.152893       0
# 2  0.148760  0.144628  0.140496  0.148760  0.152893       0
# 3  0.743802  0.764463  0.752066  0.752066  0.739669       0
# 4  0.177686  0.177686  0.177686  0.173554  0.173554       0
#
# [5 rows x 4097 columns]

# %%
print(data.shape)

print(data['target'].nunique())
# Out:
# (400, 4097)
# 40

# %%
# split the data into features and labels
X = data.drop('target', axis = 1)
y = data['target']

# %%
# split the data into training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# perform PCA on the training data using the PCA class defined above
pca = PCA_inbuilt()

pca.fit(X)

# transform the training data
X_train_pca = pca.transform(X_train)

# transform the testing data
X_test_pca = pca.transform(X_test)

# classify the testing data using Nearest Neighbor Classifier and print the accuracy
knn = KNeighborsClassifier(n_neighbors = 1)

knn.fit(X_train_pca, y_train)

pred_mindist_pca = knn.predict(X_test_pca)

print("Accuracy of the Nearest Neighbor model is: ", accuracy_score(y_test, pred_mindist_pca)*100, "%")

# classify the testing data using Naive Bayes Classifier and print the accuracy
gnb = GaussianNB()

gnb.fit(X_train_pca, y_train)

pred_nb_pca = gnb.predict(X_test_pca)

print("Accuracy of the Naive Bayes model is: ", accuracy_score(y_test, pred_nb_pca)*100, "%")
# Out:
# Variance captured by component 1 is 0.2381272934070824
# Variance captured by component 2 is 0.1399397096891601
# Variance captured by component 3 is 0.07968613661718443
# Variance captured by component 4 is 0.04998331314541593
# Variance captured by component 5 is 0.036098479765571616
# Variance captured by component 6 is 0.03156939302170363
# Variance captured by component 7 is 0.0242683231066036
# Variance captured by component 8 is 0.020363976686123345
# Variance captured by component 9 is 0.019581141191121847
# Variance captured by component 10 is 0.0167212182614893
# Variance captured by component 11 is 0.01595221736308896
# Variance captured by component 12 is 0.014369788617098303
# Variance captured by component 13 is 0.012467410668003661
# Variance captured by component 14 is 0.011471331814274077
# Variance captured by component 15 is 0.01062877361919359
# Variance captured by component 16 is 0.009777203337637454
# Variance captured by component 17 is 0.009190602830068234
# Variance captured by component 18 is 0.008155732648944819
# Variance captured by component 19 is 0.007538745267626345
# Variance captured by component 20 is 0.007469847906607365
# Variance captured by component 21 is 0.00698577777613198
# Variance captured by component 22 is 0.0061462818536571
# Variance captured by component 23 is 0.005839277154458338
# Variance captured by component 24 is 0.005697225195827736
# Variance captured by component 25 is 0.005461907833858671
# Variance captured by component 26 is 0.005318553223834545
# Variance captured by component 27 is 0.005138162215786445
# Variance captured by component 28 is 0.004958412884416541
# Variance captured by component 29 is 0.004576640687986311
# Variance captured by component 30 is 0.004411834107996221
# Variance captured by component 31 is 0.004020017097586333
# Variance captured by component 32 is 0.0038418983359426915
# Variance captured by component 33 is 0.003619509720838872
# Variance captured by component 34 is 0.0033454239027781506
# Variance captured by component 35 is 0.0032038073282607995
# Variance captured by component 36 is 0.0031604088223685244
# Variance captured by component 37 is 0.0030514732513121185
# Variance captured by component 38 is 0.002986347416002136
# Variance captured by component 39 is 0.002821410078667615
# Variance captured by component 40 is 0.002740064980368279
# Variance captured by component 41 is 0.0025977198162976363
# Variance captured by component 42 is 0.0025399036331311504
# Variance captured by component 43 is 0.002445471041734518
# Variance captured by component 44 is 0.0023983958707280363
# Variance captured by component 45 is 0.0023089040436645343
# Variance captured by component 46 is 0.00226419089289421
# Variance captured by component 47 is 0.0022228638809758637
# Variance captured by component 48 is 0.0022044294882409376
# Variance captured by component 49 is 0.002089208852152854
# Variance captured by component 50 is 0.00204983076149104
# Variance captured by component 51 is 0.0019684297451610633
# Variance captured by component 52 is 0.0019143594274265972
# Variance captured by component 53 is 0.0018504604869837198
# Variance captured by component 54 is 0.0017893896376196092
# Variance captured by component 55 is 0.0017760816807306484
# Variance captured by component 56 is 0.0017248270445377521
# Variance captured by component 57 is 0.0016858502434523074
# Variance captured by component 58 is 0.0016416816031401716
# Variance captured by component 59 is 0.001618854512238039
# Variance captured by component 60 is 0.0015839430344733335
# Variance captured by component 61 is 0.0015542828568415794
# Variance captured by component 62 is 0.0015223292748363698
# Variance captured by component 63 is 0.001499574853460071
# Variance captured by component 64 is 0.001477122136686055
# Variance captured by component 65 is 0.0014260893290194924
# Variance captured by component 66 is 0.0014059757039091765
# Variance captured by component 67 is 0.0013694106555049077
# Variance captured by component 68 is 0.0013397276318613427
# Variance captured by component 69 is 0.0013091494631867207
# Variance captured by component 70 is 0.001287196368206068
# Variance captured by component 71 is 0.0012742796508748546
# Variance captured by component 72 is 0.0012623155732883282
# Variance captured by component 73 is 0.001238007432694767
# Variance captured by component 74 is 0.0012133373716149316
# Variance captured by component 75 is 0.0011788327528411242
# Variance captured by component 76 is 0.0011488149651836773
# Variance captured by component 77 is 0.0011418428890469065
# Variance captured by component 78 is 0.0011018368270465345
# Variance captured by component 79 is 0.0010968553108639562
# Variance captured by component 80 is 0.0010862290611420942
# Variance captured by component 81 is 0.001065348431544029
# Variance captured by component 82 is 0.0010469560859607957
# Variance captured by component 83 is 0.0010168057433904277
# Variance captured by component 84 is 0.0009878099038323185
# Variance captured by component 85 is 0.0009748207306774783
# Variance captured by component 86 is 0.0009637041743557055
# Variance captured by component 87 is 0.0009559943910338694
# Variance captured by component 88 is 0.0009330974626973876
# Variance captured by component 89 is 0.0009118795367791606
# Variance captured by component 90 is 0.0009085644800464233
# Variance captured by component 91 is 0.0008905634553814759
# Variance captured by component 92 is 0.0008810698108001413
# Variance captured by component 93 is 0.0008756090085843437
# Variance captured by component 94 is 0.0008645605272422825
# Variance captured by component 95 is 0.0008253402488262947
# Variance captured by component 96 is 0.0008069017215377542
# Variance captured by component 97 is 0.0007972486082914084
# Variance captured by component 98 is 0.0007941795352070886
# Variance captured by component 99 is 0.0007866827720540767
# Variance captured by component 100 is 0.0007729614448805257
# Variance captured by component 101 is 0.0007579802598428458
# Variance captured by component 102 is 0.0007540671736349875
# Variance captured by component 103 is 0.000740207054539745
# Variance captured by component 104 is 0.0007343345977543404
# Variance captured by component 105 is 0.0007182598714221746
# Variance captured by component 106 is 0.0007115152211658929
# Variance captured by component 107 is 0.0007003357768580268
# Variance captured by component 108 is 0.0006864117913003059
# Variance captured by component 109 is 0.0006736010066356219
# Variance captured by component 110 is 0.0006679705857521279
# Variance captured by component 111 is 0.0006573960711778544
# Variance captured by component 112 is 0.0006541914790688788
# Variance captured by component 113 is 0.000639304016347765
# Variance captured by component 114 is 0.0006309524784082262
# Variance captured by component 115 is 0.0006234550237055
# Variance captured by component 116 is 0.0006209313129394368
# Variance captured by component 117 is 0.0006126213674149745
# Variance captured by component 118 is 0.0005927929943171277
# Variance captured by component 119 is 0.0005896450238140823
# Variance captured by component 120 is 0.0005797476653553514
# Variance captured by component 121 is 0.0005723901019901325
# Variance captured by component 122 is 0.0005638341284877673
# Variance captured by component 123 is 0.0005541318994107589
# Variance captured by component 124 is 0.000547773549843655
# Variance captured by component 125 is 0.0005451621852254499
# Variance captured by component 126 is 0.0005417081258412675
# Variance captured by component 127 is 0.0005382901278425742
# Variance captured by component 128 is 0.0005290126223377688
# Variance captured by component 129 is 0.0005242708843426663
# Variance captured by component 130 is 0.0005174213053898863
# Variance captured by component 131 is 0.0005118491929148845
# Variance captured by component 132 is 0.0004986279531252556
# Variance captured by component 133 is 0.0004935149032962344
# Variance captured by component 134 is 0.0004862317592130358
# Variance captured by component 135 is 0.00048093590412929177
# Variance captured by component 136 is 0.0004774162987375683
# Variance captured by component 137 is 0.00047286925257427833
# Variance captured by component 138 is 0.000466713198473543
# Variance captured by component 139 is 0.00046284430684073453
# Variance captured by component 140 is 0.00045734846944890987
# Variance captured by component 141 is 0.0004458943026364002
# Variance captured by component 142 is 0.00044386707446986937
# Variance captured by component 143 is 0.0004398315841243153
# Variance captured by component 144 is 0.00043206512515692923
# Variance captured by component 145 is 0.00042623000580365274
# Variance captured by component 146 is 0.00042452516966057886
# Variance captured by component 147 is 0.00042100339369023697
# Variance captured by component 148 is 0.0004181944707694752
# Variance captured by component 149 is 0.00041019994657913114
# Variance captured by component 150 is 0.00040742209466126814
# Variance captured by component 151 is 0.0004039566797250857
# Variance captured by component 152 is 0.00039803677974376727
# Variance captured by component 153 is 0.0003963635170432393
# Variance captured by component 154 is 0.00039101506889099006
# Variance captured by component 155 is 0.000388758810310268
# Variance captured by component 156 is 0.0003866355219202529
# Variance captured by component 157 is 0.00038088251880275046
# Variance captured by component 158 is 0.00037404869687782284
# Variance captured by component 159 is 0.0003718953725586331
# Variance captured by component 160 is 0.0003694004717528555
# Variance captured by component 161 is 0.00036542490929831036
# Variance captured by component 162 is 0.00036181441913016
# Variance captured by component 163 is 0.0003592154023845181
# Variance captured by component 164 is 0.00035497217078570877
# Variance captured by component 165 is 0.0003500077516254104
# Variance captured by component 166 is 0.0003469812949749175
# Variance captured by component 167 is 0.0003431370498328683
# Variance captured by component 168 is 0.0003378333849976037
# Variance captured by component 169 is 0.00033651661132786564
# Variance captured by component 170 is 0.0003312148130333122
# Variance captured by component 171 is 0.0003303191470224296
# Variance captured by component 172 is 0.0003279696277153087
# Variance captured by component 173 is 0.00032204190350859597
# Variance captured by component 174 is 0.0003182985455901399
# Variance captured by component 175 is 0.00031311031067092737
# Variance captured by component 176 is 0.0003119265906447432
# Variance captured by component 177 is 0.00031159656141709866
# Variance captured by component 178 is 0.00030611026479038895
# Variance captured by component 179 is 0.0003039309731963566
# Variance captured by component 180 is 0.00030068876303052615
# Variance captured by component 181 is 0.00029513622076575067
# Variance captured by component 182 is 0.0002922436124634371
# Variance captured by component 183 is 0.00028806486472179925
# Variance captured by component 184 is 0.00028459801424791426
# Variance captured by component 185 is 0.00028077685424685847
# Variance captured by component 186 is 0.00027885167138597746
# Variance captured by component 187 is 0.0002737051222026857
# Variance captured by component 188 is 0.0002729178286482211
# Variance captured by component 189 is 0.0002695673818582996
# Variance captured by component 190 is 0.00026830571783699854
# Variance captured by component 191 is 0.0002657593112299664
# Variance captured by component 192 is 0.0002628014935755861
# Variance captured by component 193 is 0.00026069185295364664
# Variance captured by component 194 is 0.00025793945144076395
# Variance captured by component 195 is 0.0002564876652210164
# Variance captured by component 196 is 0.00025288343681073317
# Variance captured by component 197 is 0.0002505993695873309
# Variance captured by component 198 is 0.0002488960082013261
# Variance captured by component 199 is 0.0002464416071274815
# Variance captured by component 200 is 0.00023994731512692684
# Variance captured by component 201 is 0.00023885437978786865
# Variance captured by component 202 is 0.0002350431750004921
# Variance captured by component 203 is 0.00023473189625737096
# Variance captured by component 204 is 0.00023357086448589216
# Variance captured by component 205 is 0.00023190817828525382
# Variance captured by component 206 is 0.00022802623291925955
# Variance captured by component 207 is 0.00022708377395912744
# Variance captured by component 208 is 0.00022603088768971286
# Variance captured by component 209 is 0.0002239981598301437
# Variance captured by component 210 is 0.0002197954759368268
# Variance captured by component 211 is 0.00021836124474700747
# Variance captured by component 212 is 0.0002164972641281412
# Variance captured by component 213 is 0.0002141253507916064
# Variance captured by component 214 is 0.00021058075203954268
# Variance captured by component 215 is 0.00020944801118313847
# Variance captured by component 216 is 0.00020913903155283614
# Variance captured by component 217 is 0.00020338280797528628
# Variance captured by component 218 is 0.00020253326332594272
# Variance captured by component 219 is 0.00019945467872324322
# Variance captured by component 220 is 0.00019827836377925273
# Variance captured by component 221 is 0.00019552431765190574
# Variance captured by component 222 is 0.00019467456919667443
# Variance captured by component 223 is 0.0001938515924460077
# Variance captured by component 224 is 0.00019151937237454208
# Variance captured by component 225 is 0.00018965673462547323
# Variance captured by component 226 is 0.00018872706917411522
# Variance captured by component 227 is 0.00018552446449144626
# Variance captured by component 228 is 0.00018515827493047137
# Variance captured by component 229 is 0.00018382667690405486
# Variance captured by component 230 is 0.00018208157404347812
# Variance captured by component 231 is 0.00018141509311508564
# Variance captured by component 232 is 0.00017871760516884947
# Variance captured by component 233 is 0.00017581662214277846
# Variance captured by component 234 is 0.00017396664291094568
# Variance captured by component 235 is 0.00017153182835231816
# Variance captured by component 236 is 0.00017011503849198792
# Variance captured by component 237 is 0.0001676412754912249
# Variance captured by component 238 is 0.00016672286522807227
# Variance captured by component 239 is 0.00016563655366821396
# Variance captured by component 240 is 0.0001648001129134609
# Variance captured by component 241 is 0.00016142179447925197
# Variance captured by component 242 is 0.0001603501335629162
# Variance captured by component 243 is 0.000159147216125119
# Variance captured by component 244 is 0.00015752652723617319
# Variance captured by component 245 is 0.00015651260844929839
# Variance captured by component 246 is 0.00015481363659645858
# Variance captured by component 247 is 0.0001531270149090612
# Variance captured by component 248 is 0.00015280840505617026
# Variance captured by component 249 is 0.0001509196123300008
# Variance captured by component 250 is 0.00014862182158561889
# Variance captured by component 251 is 0.00014805410009183917
# Variance captured by component 252 is 0.00014527330972248756
# Variance captured by component 253 is 0.00014494508700590482
# Variance captured by component 254 is 0.00014270887780103045
# Variance captured by component 255 is 0.0001405165214488733
# Variance captured by component 256 is 0.00013978727857848807
# Variance captured by component 257 is 0.00013843665742503068
# Variance captured by component 258 is 0.0001381032486438068
# Variance captured by component 259 is 0.0001376897538262721
# Variance captured by component 260 is 0.000135762642151911
# Variance captured by component 261 is 0.00013431553829302558
# Variance captured by component 262 is 0.0001332101459431024
# Variance captured by component 263 is 0.00013222143188231167
# Variance captured by component 264 is 0.00013047377240437476
# Variance captured by component 265 is 0.0001284828308770894
# Variance captured by component 266 is 0.0001275202504270412
# Variance captured by component 267 is 0.0001267176873512886
# Variance captured by component 268 is 0.00012626183562959597
# Variance captured by component 269 is 0.00012516740080166386
# Variance captured by component 270 is 0.0001232799820744859
# Variance captured by component 271 is 0.00012247514600065138
# Variance captured by component 272 is 0.0001210703926957304
# Variance captured by component 273 is 0.00012059446559340547
# Variance captured by component 274 is 0.00011949711986542128
# Variance captured by component 275 is 0.00011816111646013588
# Variance captured by component 276 is 0.00011688648765948628
# Variance captured by component 277 is 0.00011639930236793979
# Variance captured by component 278 is 0.0001152336704869836
# Variance captured by component 279 is 0.00011387360334211295
# Variance captured by component 280 is 0.00011280218804295181
# Variance captured by component 281 is 0.00011210788745262323
# Variance captured by component 282 is 0.00011109192416147769
# Variance captured by component 283 is 0.00011000624594974675
# Variance captured by component 284 is 0.00010932024694458764
# Variance captured by component 285 is 0.0001086383222597283
# Variance captured by component 286 is 0.00010807493608256569
# Variance captured by component 287 is 0.00010672347722927235
# Variance captured by component 288 is 0.00010636294415332189
# Variance captured by component 289 is 0.0001046366253402544
# Variance captured by component 290 is 0.0001031676975102406
# Variance captured by component 291 is 0.00010172322965968755
# Variance captured by component 292 is 0.00010050675521474315
# Variance captured by component 293 is 9.911311713802703e-05
# Variance captured by component 294 is 9.779891084308019e-05
# Variance captured by component 295 is 9.733267436585103e-05
# Variance captured by component 296 is 9.647975186035347e-05
# Variance captured by component 297 is 9.578355485694282e-05
# Variance captured by component 298 is 9.482371378920408e-05
# Variance captured by component 299 is 9.406484794698493e-05
# Variance captured by component 300 is 9.312194542987449e-05
# Variance captured by component 301 is 9.270732629396562e-05
# Variance captured by component 302 is 9.12857178055513e-05
# Variance captured by component 303 is 9.057722975919871e-05
# Variance captured by component 304 is 9.041769285865368e-05
# Variance captured by component 305 is 8.970768212130616e-05
# Variance captured by component 306 is 8.666975162914957e-05
# Variance captured by component 307 is 8.6354613747056e-05
# Variance captured by component 308 is 8.52006198334995e-05
# Variance captured by component 309 is 8.452092389238501e-05
# Variance captured by component 310 is 8.388932888140756e-05
# Variance captured by component 311 is 8.364964278752976e-05
# Variance captured by component 312 is 8.251035607395971e-05
# Variance captured by component 313 is 8.236086817635491e-05
# Variance captured by component 314 is 8.153831864716604e-05
# Variance captured by component 315 is 7.948028729329765e-05
# Variance captured by component 316 is 7.922162279899585e-05
# Variance captured by component 317 is 7.900128251352674e-05
# Variance captured by component 318 is 7.777434503324524e-05
# Variance captured by component 319 is 7.722127392761917e-05
# Variance captured by component 320 is 7.603873832619663e-05
# Variance captured by component 321 is 7.588348282271947e-05
# Variance captured by component 322 is 7.524273048646466e-05
# Variance captured by component 323 is 7.371872925164272e-05
# Variance captured by component 324 is 7.285987711168457e-05
# Variance captured by component 325 is 7.200912016149043e-05
# Variance captured by component 326 is 7.123976638452214e-05
# Variance captured by component 327 is 7.067404956359839e-05
# Variance captured by component 328 is 7.014548054535083e-05
# Variance captured by component 329 is 6.939938033349227e-05
# Variance captured by component 330 is 6.898390393093163e-05
# Variance captured by component 331 is 6.878945444820836e-05
# Variance captured by component 332 is 6.77068378987724e-05
# Variance captured by component 333 is 6.735337081524226e-05
# Variance captured by component 334 is 6.623887890612718e-05
# Variance captured by component 335 is 6.50742103766217e-05
# Variance captured by component 336 is 6.477922915070178e-05
# Variance captured by component 337 is 6.416700182731518e-05
# Variance captured by component 338 is 6.333498181185865e-05
# Variance captured by component 339 is 6.235518885239216e-05
# Variance captured by component 340 is 6.1471387292298e-05
# Variance captured by component 341 is 6.095059703876163e-05
# Variance captured by component 342 is 6.046634740185491e-05
# Variance captured by component 343 is 5.9530183719357816e-05
# Variance captured by component 344 is 5.8095973971735476e-05
# Variance captured by component 345 is 5.7704972527733944e-05
# Variance captured by component 346 is 5.7620225063053034e-05
# Variance captured by component 347 is 5.682032686425583e-05
# Variance captured by component 348 is 5.6049448110893943e-05
# Variance captured by component 349 is 5.4782926565450056e-05
# Variance captured by component 350 is 5.4706945772458926e-05
# Variance captured by component 351 is 5.332293689938887e-05
# Variance captured by component 352 is 5.302431851864718e-05
# Variance captured by component 353 is 5.1807116328521726e-05
# Variance captured by component 354 is 5.1398634279245444e-05
# Variance captured by component 355 is 5.084782575951599e-05
# Variance captured by component 356 is 5.009485233505413e-05
# Variance captured by component 357 is 4.938414012792129e-05
# Variance captured by component 358 is 4.935667866976955e-05
# Variance captured by component 359 is 4.843789735932535e-05
# Variance captured by component 360 is 4.759508426660136e-05
# Variance captured by component 361 is 4.735825152251813e-05
# Variance captured by component 362 is 4.6415436053561086e-05
# Variance captured by component 363 is 4.631250106341436e-05
# Variance captured by component 364 is 4.5681492238859325e-05
# Variance captured by component 365 is 4.4730261223138214e-05
# Variance captured by component 366 is 4.385274999391238e-05
# Variance captured by component 367 is 4.3136590663824195e-05
# Variance captured by component 368 is 4.2028066702621716e-05
# Variance captured by component 369 is 4.171141978332129e-05
# Variance captured by component 370 is 4.136823047863821e-05
# Variance captured by component 371 is 4.089815193242655e-05
# Variance captured by component 372 is 4.0229776405103156e-05
# Variance captured by component 373 is 3.9628243573448345e-05
# Variance captured by component 374 is 3.902175035192126e-05
# Variance captured by component 375 is 3.869479822344842e-05
# Variance captured by component 376 is 3.802800407657341e-05
# Variance captured by component 377 is 3.788238263198517e-05
# Variance captured by component 378 is 3.6486628339351025e-05
# Variance captured by component 379 is 3.6083378979568105e-05
# Variance captured by component 380 is 3.5528886957526606e-05
# Variance captured by component 381 is 3.426010526099543e-05
# Variance captured by component 382 is 3.37837245492283e-05
# Variance captured by component 383 is 3.306738599003365e-05
# Variance captured by component 384 is 3.286914174940302e-05
# Variance captured by component 385 is 3.212104434167466e-05
# Variance captured by component 386 is 3.17952760400906e-05
# Variance captured by component 387 is 3.1074581386161464e-05
# Variance captured by component 388 is 3.0401770619017616e-05
# Variance captured by component 389 is 2.9344012770940564e-05
# Variance captured by component 390 is 2.8035251328735423e-05
# Variance captured by component 391 is 2.7060065808658624e-05
# Variance captured by component 392 is 2.6003481110533636e-05
# Variance captured by component 393 is 2.4909053504274966e-05
# Variance captured by component 394 is 2.4002025538276868e-05
# Variance captured by component 395 is 2.2046931493792065e-05
# Variance captured by component 396 is 2.17639336773776e-05
# Variance captured by component 397 is 2.1414592097337484e-05
# Variance captured by component 398 is 2.0023859045515754e-05
# Variance captured by component 399 is 1.6397596298628065e-05
# Variance captured by component 400 is 5.4124761569890814e-18
# Variance captured by component 401 is 5.4124761569890814e-18
# Variance captured by component 402 is 5.0174484404434285e-18
# Variance captured by component 403 is 5.0174484404434285e-18
# Variance captured by component 404 is 4.190208675367406e-18
# Variance captured by component 405 is 3.677831936537247e-18
# Variance captured by component 406 is 3.677831936537247e-18
# Variance captured by component 407 is 3.419599989965728e-18
# Variance captured by component 408 is 3.38816438043349e-18
# Variance captured by component 409 is 3.38816438043349e-18
# Variance captured by component 410 is 3.2587399633958975e-18
# Variance captured by component 411 is 3.2587399633958975e-18
# Variance captured by component 412 is 3.1836849523894655e-18
# Variance captured by component 413 is 3.1836849523894655e-18
# Variance captured by component 414 is 2.67166591416693e-18
# Variance captured by component 415 is 2.669160876366846e-18
# Variance captured by component 416 is 2.669160876366846e-18
# Variance captured by component 417 is 2.4227319053883217e-18
# Variance captured by component 418 is 2.420200292276457e-18
# Variance captured by component 419 is 2.420200292276457e-18
# Variance captured by component 420 is 2.4114297521581022e-18
# Variance captured by component 421 is 2.4114297521581022e-18
# Variance captured by component 422 is 2.376594420580881e-18
# Variance captured by component 423 is 2.376594420580881e-18
# Variance captured by component 424 is 2.369548628272389e-18
# Variance captured by component 425 is 2.369548628272389e-18
# Variance captured by component 426 is 2.319201042439682e-18
# Variance captured by component 427 is 2.319201042439682e-18
# Variance captured by component 428 is 2.2969936032814864e-18
# Variance captured by component 429 is 2.2969936032814864e-18
# Variance captured by component 430 is 2.259667280291671e-18
# Variance captured by component 431 is 2.2501290841368043e-18
# Variance captured by component 432 is 2.245993728443177e-18
# Variance captured by component 433 is 2.245993728443177e-18
# Variance captured by component 434 is 2.222921155630678e-18
# Variance captured by component 435 is 2.222921155630678e-18
# Variance captured by component 436 is 2.213290070051451e-18
# Variance captured by component 437 is 2.213290070051451e-18
# Variance captured by component 438 is 2.1963353442544096e-18
# Variance captured by component 439 is 2.1963353442544096e-18
# Variance captured by component 440 is 2.192525661433158e-18
# Variance captured by component 441 is 2.192525661433158e-18
# Variance captured by component 442 is 2.1890260822991697e-18
# Variance captured by component 443 is 2.1890260822991697e-18
# Variance captured by component 444 is 2.1811011054663718e-18
# Variance captured by component 445 is 2.1811011054663718e-18
# Variance captured by component 446 is 2.179045471959996e-18
# Variance captured by component 447 is 2.17739385200755e-18
# Variance captured by component 448 is 2.17739385200755e-18
# Variance captured by component 449 is 2.1733247209560498e-18
# Variance captured by component 450 is 2.1733247209560498e-18
# Variance captured by component 451 is 2.1726559963800474e-18
# Variance captured by component 452 is 2.1726559963800474e-18
# Variance captured by component 453 is 2.1636958284987013e-18
# Variance captured by component 454 is 2.1608627637813117e-18
# Variance captured by component 455 is 2.1608627637813117e-18
# Variance captured by component 456 is 2.1570097751188924e-18
# Variance captured by component 457 is 2.1570097751188924e-18
# Variance captured by component 458 is 2.15109210953997e-18
# Variance captured by component 459 is 2.15109210953997e-18
# Variance captured by component 460 is 2.146856985049478e-18
# Variance captured by component 461 is 2.146856985049478e-18
# Variance captured by component 462 is 2.139087236267369e-18
# Variance captured by component 463 is 2.139087236267369e-18
# Variance captured by component 464 is 2.1225529092356006e-18
# Variance captured by component 465 is 2.1205635669124502e-18
# Variance captured by component 466 is 2.1205635669124502e-18
# Variance captured by component 467 is 2.115679156574085e-18
# Variance captured by component 468 is 2.115679156574085e-18
# Variance captured by component 469 is 2.109293393496982e-18
# Variance captured by component 470 is 2.109293393496982e-18
# Variance captured by component 471 is 2.1055504932801023e-18
# Variance captured by component 472 is 2.1055504932801023e-18
# Variance captured by component 473 is 2.1038350739519406e-18
# Variance captured by component 474 is 2.1038350739519406e-18
# Variance captured by component 475 is 2.099778649837861e-18
# Variance captured by component 476 is 2.099778649837861e-18
# Variance captured by component 477 is 2.097222322004281e-18
# Variance captured by component 478 is 2.097222322004281e-18
# Variance captured by component 479 is 2.0951952282909876e-18
# Variance captured by component 480 is 2.0951952282909876e-18
# Variance captured by component 481 is 2.0877988152654556e-18
# Variance captured by component 482 is 2.0877988152654556e-18
# Variance captured by component 483 is 2.0877601313696926e-18
# Variance captured by component 484 is 2.0877601313696926e-18
# Variance captured by component 485 is 2.0756778956599138e-18
# Variance captured by component 486 is 2.0756778956599138e-18
# Variance captured by component 487 is 2.072975603676336e-18
# Variance captured by component 488 is 2.0569754816907937e-18
# Variance captured by component 489 is 2.0440821743585552e-18
# Variance captured by component 490 is 2.0440821743585552e-18
# Variance captured by component 491 is 2.03584307957506e-18
# Variance captured by component 492 is 2.03584307957506e-18
# Variance captured by component 493 is 2.031549670740166e-18
# Variance captured by component 494 is 2.031549670740166e-18
# Variance captured by component 495 is 2.030044322615343e-18
# Variance captured by component 496 is 2.030044322615343e-18
# Variance captured by component 497 is 2.024968950285925e-18
# Variance captured by component 498 is 2.024968950285925e-18
# Variance captured by component 499 is 2.024491211514904e-18
# Variance captured by component 500 is 2.024491211514904e-18
# Variance captured by component 501 is 2.0175565407193795e-18
# Variance captured by component 502 is 2.0175565407193795e-18
# Variance captured by component 503 is 2.016919332282812e-18
# Variance captured by component 504 is 2.0122398292887753e-18
# Variance captured by component 505 is 2.0122398292887753e-18
# Variance captured by component 506 is 2.006028686117931e-18
# Variance captured by component 507 is 2.006028686117931e-18
# Variance captured by component 508 is 1.9983085264212575e-18
# Variance captured by component 509 is 1.9983085264212575e-18
# Variance captured by component 510 is 1.997774480963045e-18
# Variance captured by component 511 is 1.997774480963045e-18
# Variance captured by component 512 is 1.997453986467484e-18
# Variance captured by component 513 is 1.997453986467484e-18
# Variance captured by component 514 is 1.9872244125352267e-18
# Variance captured by component 515 is 1.9872244125352267e-18
# Variance captured by component 516 is 1.986239191649813e-18
# Variance captured by component 517 is 1.986239191649813e-18
# Variance captured by component 518 is 1.9814543159504205e-18
# Variance captured by component 519 is 1.9814543159504205e-18
# Variance captured by component 520 is 1.9755913346668822e-18
# Variance captured by component 521 is 1.9755913346668822e-18
# Variance captured by component 522 is 1.968931803405635e-18
# Variance captured by component 523 is 1.968931803405635e-18
# Variance captured by component 524 is 1.966220757579708e-18
# Variance captured by component 525 is 1.958514972083811e-18
# Variance captured by component 526 is 1.958514972083811e-18
# Variance captured by component 527 is 1.9582847783373774e-18
# Variance captured by component 528 is 1.9582847783373774e-18
# Variance captured by component 529 is 1.9570132763162528e-18
# Variance captured by component 530 is 1.9570132763162528e-18
# Variance captured by component 531 is 1.956506140125018e-18
# Variance captured by component 532 is 1.956506140125018e-18
# Variance captured by component 533 is 1.9561823744123745e-18
# Variance captured by component 534 is 1.9561823744123745e-18
# Variance captured by component 535 is 1.9524539553135422e-18
# Variance captured by component 536 is 1.9524539553135422e-18
# Variance captured by component 537 is 1.9504095350771073e-18
# Variance captured by component 538 is 1.9477947362850014e-18
# Variance captured by component 539 is 1.9477947362850014e-18
# Variance captured by component 540 is 1.9446411615207953e-18
# Variance captured by component 541 is 1.9446411615207953e-18
# Variance captured by component 542 is 1.9388951432134043e-18
# Variance captured by component 543 is 1.9388951432134043e-18
# Variance captured by component 544 is 1.9380894023634556e-18
# Variance captured by component 545 is 1.9380894023634556e-18
# Variance captured by component 546 is 1.9375607032500334e-18
# Variance captured by component 547 is 1.9375607032500334e-18
# Variance captured by component 548 is 1.9321107690608732e-18
# Variance captured by component 549 is 1.9321107690608732e-18
# Variance captured by component 550 is 1.930000951584804e-18
# Variance captured by component 551 is 1.930000951584804e-18
# Variance captured by component 552 is 1.923696208001544e-18
# Variance captured by component 553 is 1.923696208001544e-18
# Variance captured by component 554 is 1.9167188626297483e-18
# Variance captured by component 555 is 1.9167188626297483e-18
# Variance captured by component 556 is 1.9164471547241352e-18
# Variance captured by component 557 is 1.9164471547241352e-18
# Variance captured by component 558 is 1.914052247412803e-18
# Variance captured by component 559 is 1.914052247412803e-18
# Variance captured by component 560 is 1.9134999804528563e-18
# Variance captured by component 561 is 1.9134999804528563e-18
# Variance captured by component 562 is 1.911260269138179e-18
# Variance captured by component 563 is 1.911260269138179e-18
# Variance captured by component 564 is 1.9110526199056118e-18
# Variance captured by component 565 is 1.9110526199056118e-18
# Variance captured by component 566 is 1.9107022613609835e-18
# Variance captured by component 567 is 1.9107022613609835e-18
# Variance captured by component 568 is 1.9095762888253844e-18
# Variance captured by component 569 is 1.9095762888253844e-18
# Variance captured by component 570 is 1.9033969428563032e-18
# Variance captured by component 571 is 1.9033969428563032e-18
# Variance captured by component 572 is 1.8992206709464003e-18
# Variance captured by component 573 is 1.8977602075843818e-18
# Variance captured by component 574 is 1.8977602075843818e-18
# Variance captured by component 575 is 1.8887771239810537e-18
# Variance captured by component 576 is 1.8887771239810537e-18
# Variance captured by component 577 is 1.8885113373356343e-18
# Variance captured by component 578 is 1.8885113373356343e-18
# Variance captured by component 579 is 1.8864263765129014e-18
# Variance captured by component 580 is 1.8864263765129014e-18
# Variance captured by component 581 is 1.8803541985427784e-18
# Variance captured by component 582 is 1.8803541985427784e-18
# Variance captured by component 583 is 1.877221427717484e-18
# Variance captured by component 584 is 1.875029593844583e-18
# Variance captured by component 585 is 1.875029593844583e-18
# Variance captured by component 586 is 1.8746398930909506e-18
# Variance captured by component 587 is 1.8746398930909506e-18
# Variance captured by component 588 is 1.87109387626386e-18
# Variance captured by component 589 is 1.87109387626386e-18
# Variance captured by component 590 is 1.8689676303293745e-18
# Variance captured by component 591 is 1.8689676303293745e-18
# Variance captured by component 592 is 1.8663312191430844e-18
# Variance captured by component 593 is 1.8663312191430844e-18
# Variance captured by component 594 is 1.865701459052196e-18
# Variance captured by component 595 is 1.8655781538458083e-18
# Variance captured by component 596 is 1.8655781538458083e-18
# Variance captured by component 597 is 1.8596904380672015e-18
# Variance captured by component 598 is 1.8596904380672015e-18
# Variance captured by component 599 is 1.8590125541225314e-18
# Variance captured by component 600 is 1.8590125541225314e-18
# Variance captured by component 601 is 1.85605376422406e-18
# Variance captured by component 602 is 1.85605376422406e-18
# Variance captured by component 603 is 1.8537670379071674e-18
# Variance captured by component 604 is 1.8537670379071674e-18
# Variance captured by component 605 is 1.846621053533612e-18
# Variance captured by component 606 is 1.846621053533612e-18
# Variance captured by component 607 is 1.8430201438848445e-18
# Variance captured by component 608 is 1.8430201438848445e-18
# Variance captured by component 609 is 1.8412791581004687e-18
# Variance captured by component 610 is 1.8412791581004687e-18
# Variance captured by component 611 is 1.8406023670574347e-18
# Variance captured by component 612 is 1.8406023670574347e-18
# Variance captured by component 613 is 1.8404121327870462e-18
# Variance captured by component 614 is 1.8404121327870462e-18
# Variance captured by component 615 is 1.839663241697337e-18
# Variance captured by component 616 is 1.8376787612817284e-18
# Variance captured by component 617 is 1.8376787612817284e-18
# Variance captured by component 618 is 1.8303213826180474e-18
# Variance captured by component 619 is 1.8303213826180474e-18
# Variance captured by component 620 is 1.8291745871031072e-18
# Variance captured by component 621 is 1.8291745871031072e-18
# Variance captured by component 622 is 1.826694052797346e-18
# Variance captured by component 623 is 1.826694052797346e-18
# Variance captured by component 624 is 1.8261102754009747e-18
# Variance captured by component 625 is 1.8261102754009747e-18
# Variance captured by component 626 is 1.825980166833545e-18
# Variance captured by component 627 is 1.825980166833545e-18
# Variance captured by component 628 is 1.8227299246323015e-18
# Variance captured by component 629 is 1.8227299246323015e-18
# Variance captured by component 630 is 1.8188228483037853e-18
# Variance captured by component 631 is 1.8188228483037853e-18
# Variance captured by component 632 is 1.8174136004359844e-18
# Variance captured by component 633 is 1.8174136004359844e-18
# Variance captured by component 634 is 1.816631277648969e-18
# Variance captured by component 635 is 1.816631277648969e-18
# Variance captured by component 636 is 1.8152826075540542e-18
# Variance captured by component 637 is 1.8152826075540542e-18
# Variance captured by component 638 is 1.8123520055111903e-18
# Variance captured by component 639 is 1.8123520055111903e-18
# Variance captured by component 640 is 1.8112874052409034e-18
# Variance captured by component 641 is 1.8112874052409034e-18
# Variance captured by component 642 is 1.8101316237247704e-18
# Variance captured by component 643 is 1.8101316237247704e-18
# Variance captured by component 644 is 1.7962637101892803e-18
# Variance captured by component 645 is 1.7962637101892803e-18
# Variance captured by component 646 is 1.795929969756343e-18
# Variance captured by component 647 is 1.795929969756343e-18
# Variance captured by component 648 is 1.791170581396497e-18
# Variance captured by component 649 is 1.791170581396497e-18
# Variance captured by component 650 is 1.7905647284047915e-18
# Variance captured by component 651 is 1.7905647284047915e-18
# Variance captured by component 652 is 1.7902076140442414e-18
# Variance captured by component 653 is 1.7902076140442414e-18
# Variance captured by component 654 is 1.7887511204529725e-18
# Variance captured by component 655 is 1.7887511204529725e-18
# Variance captured by component 656 is 1.7884459949993745e-18
# Variance captured by component 657 is 1.7884459949993745e-18
# Variance captured by component 658 is 1.786609280654873e-18
# Variance captured by component 659 is 1.786609280654873e-18
# Variance captured by component 660 is 1.786171923433649e-18
# Variance captured by component 661 is 1.786171923433649e-18
# Variance captured by component 662 is 1.783711416015279e-18
# Variance captured by component 663 is 1.783711416015279e-18
# Variance captured by component 664 is 1.783434470724172e-18
# Variance captured by component 665 is 1.783434470724172e-18
# Variance captured by component 666 is 1.7745952506687535e-18
# Variance captured by component 667 is 1.7745952506687535e-18
# Variance captured by component 668 is 1.7708002711484835e-18
# Variance captured by component 669 is 1.7708002711484835e-18
# Variance captured by component 670 is 1.76801703868427e-18
# Variance captured by component 671 is 1.76801703868427e-18
# Variance captured by component 672 is 1.76602797923536e-18
# Variance captured by component 673 is 1.76602797923536e-18
# Variance captured by component 674 is 1.7656352506227177e-18
# Variance captured by component 675 is 1.7656352506227177e-18
# Variance captured by component 676 is 1.759741868243661e-18
# Variance captured by component 677 is 1.759741868243661e-18
# Variance captured by component 678 is 1.7590880254168447e-18
# Variance captured by component 679 is 1.7590880254168447e-18
# Variance captured by component 680 is 1.7583410775968855e-18
# Variance captured by component 681 is 1.7583410775968855e-18
# Variance captured by component 682 is 1.7562117962311275e-18
# Variance captured by component 683 is 1.7562117962311275e-18
# Variance captured by component 684 is 1.7532534827634687e-18
# Variance captured by component 685 is 1.7532534827634687e-18
# Variance captured by component 686 is 1.7502866860764813e-18
# Variance captured by component 687 is 1.7502866860764813e-18
# Variance captured by component 688 is 1.746700303337879e-18
# Variance captured by component 689 is 1.746700303337879e-18
# Variance captured by component 690 is 1.744267385666312e-18
# Variance captured by component 691 is 1.744267385666312e-18
# Variance captured by component 692 is 1.743194706904801e-18
# Variance captured by component 693 is 1.743194706904801e-18
# Variance captured by component 694 is 1.7423943921848533e-18
# Variance captured by component 695 is 1.7423943921848533e-18
# Variance captured by component 696 is 1.7422673219650704e-18
# Variance captured by component 697 is 1.7422673219650704e-18
# Variance captured by component 698 is 1.7355988106044575e-18
# Variance captured by component 699 is 1.7355988106044575e-18
# Variance captured by component 700 is 1.728432351779041e-18
# Variance captured by component 701 is 1.728432351779041e-18
# Variance captured by component 702 is 1.7273542128029921e-18
# Variance captured by component 703 is 1.7273542128029921e-18
# Variance captured by component 704 is 1.7230314025690213e-18
# Variance captured by component 705 is 1.7230314025690213e-18
# Variance captured by component 706 is 1.7226476161377899e-18
# Variance captured by component 707 is 1.7226476161377899e-18
# Variance captured by component 708 is 1.7223307385320595e-18
# Variance captured by component 709 is 1.7223307385320595e-18
# Variance captured by component 710 is 1.7208908607760423e-18
# Variance captured by component 711 is 1.7208908607760423e-18
# Variance captured by component 712 is 1.7204331885661432e-18
# Variance captured by component 713 is 1.7204331885661432e-18
# Variance captured by component 714 is 1.7170480681195775e-18
# Variance captured by component 715 is 1.7170480681195775e-18
# Variance captured by component 716 is 1.716024102148542e-18
# Variance captured by component 717 is 1.716024102148542e-18
# Variance captured by component 718 is 1.7152437118313004e-18
# Variance captured by component 719 is 1.7152168910418073e-18
# Variance captured by component 720 is 1.7152168910418073e-18
# Variance captured by component 721 is 1.7146317789972972e-18
# Variance captured by component 722 is 1.7146317789972972e-18
# Variance captured by component 723 is 1.7137262388919054e-18
# Variance captured by component 724 is 1.7137262388919054e-18
# Variance captured by component 725 is 1.7099884828468209e-18
# Variance captured by component 726 is 1.7099884828468209e-18
# Variance captured by component 727 is 1.7065494494674632e-18
# Variance captured by component 728 is 1.7065494494674632e-18
# Variance captured by component 729 is 1.7047819315206836e-18
# Variance captured by component 730 is 1.7047819315206836e-18
# Variance captured by component 731 is 1.6996206723007288e-18
# Variance captured by component 732 is 1.6996206723007288e-18
# Variance captured by component 733 is 1.6982757284163827e-18
# Variance captured by component 734 is 1.6982757284163827e-18
# Variance captured by component 735 is 1.6967393978238046e-18
# Variance captured by component 736 is 1.6967393978238046e-18
# Variance captured by component 737 is 1.6960660194557281e-18
# Variance captured by component 738 is 1.6960660194557281e-18
# Variance captured by component 739 is 1.6945009685477912e-18
# Variance captured by component 740 is 1.6945009685477912e-18
# Variance captured by component 741 is 1.6916889584192507e-18
# Variance captured by component 742 is 1.6916889584192507e-18
# Variance captured by component 743 is 1.6909676112008748e-18
# Variance captured by component 744 is 1.6909676112008748e-18
# Variance captured by component 745 is 1.6893397685625646e-18
# Variance captured by component 746 is 1.6893397685625646e-18
# Variance captured by component 747 is 1.689246471969294e-18
# Variance captured by component 748 is 1.689246471969294e-18
# Variance captured by component 749 is 1.6891987335022332e-18
# Variance captured by component 750 is 1.6891987335022332e-18
# Variance captured by component 751 is 1.687790783377045e-18
# Variance captured by component 752 is 1.687790783377045e-18
# Variance captured by component 753 is 1.687517332557898e-18
# Variance captured by component 754 is 1.687517332557898e-18
# Variance captured by component 755 is 1.6833839277448699e-18
# Variance captured by component 756 is 1.6833839277448699e-18
# Variance captured by component 757 is 1.681487059818851e-18
# Variance captured by component 758 is 1.681487059818851e-18
# Variance captured by component 759 is 1.6801734181799641e-18
# Variance captured by component 760 is 1.6801734181799641e-18
# Variance captured by component 761 is 1.6708882764354208e-18
# Variance captured by component 762 is 1.6708882764354208e-18
# Variance captured by component 763 is 1.6707846617613881e-18
# Variance captured by component 764 is 1.6707846617613881e-18
# Variance captured by component 765 is 1.6705698477658579e-18
# Variance captured by component 766 is 1.6705698477658579e-18
# Variance captured by component 767 is 1.6684074601276443e-18
# Variance captured by component 768 is 1.6684074601276443e-18
# Variance captured by component 769 is 1.6663844822674032e-18
# Variance captured by component 770 is 1.6663844822674032e-18
# Variance captured by component 771 is 1.663342053251681e-18
# Variance captured by component 772 is 1.663342053251681e-18
# Variance captured by component 773 is 1.6603028058918295e-18
# Variance captured by component 774 is 1.6603028058918295e-18
# Variance captured by component 775 is 1.6595632374952112e-18
# Variance captured by component 776 is 1.6595632374952112e-18
# Variance captured by component 777 is 1.6593717549394933e-18
# Variance captured by component 778 is 1.6593717549394933e-18
# Variance captured by component 779 is 1.657663433534124e-18
# Variance captured by component 780 is 1.657663433534124e-18
# Variance captured by component 781 is 1.6566893721261416e-18
# Variance captured by component 782 is 1.6566893721261416e-18
# Variance captured by component 783 is 1.656589625100913e-18
# Variance captured by component 784 is 1.6559610773036791e-18
# Variance captured by component 785 is 1.6559610773036791e-18
# Variance captured by component 786 is 1.6551813688010506e-18
# Variance captured by component 787 is 1.6551813688010506e-18
# Variance captured by component 788 is 1.6541030965028092e-18
# Variance captured by component 789 is 1.6541030965028092e-18
# Variance captured by component 790 is 1.6513480893305166e-18
# Variance captured by component 791 is 1.6513480893305166e-18
# Variance captured by component 792 is 1.6512339930685975e-18
# Variance captured by component 793 is 1.6512339930685975e-18
# Variance captured by component 794 is 1.6510051259974974e-18
# Variance captured by component 795 is 1.6510051259974974e-18
# Variance captured by component 796 is 1.649975715300511e-18
# Variance captured by component 797 is 1.6496570304385957e-18
# ...
# Variance captured by component 3838 is 1.0203636953753107e-19
# Variance captured by component 3839 is 1.0163855324643117e-19
# Variance captured by component 3840 is 1.0163855324643117e-19
# Variance captured by component 3841 is 9.96961058722363e-20
# Variance captured by component 3842 is 9.96961058722363e-20
# Variance captured by component 3843 is 9.952086327106674e-20
# Variance captured by component 3844 is 9.952086327106674e-20
# Variance captured by component 3845 is 9.950848919366506e-20
# Variance captured by component 3846 is 9.950848919366506e-20
# Variance captured by component 3847 is 9.912009384365458e-20
# Variance captured by component 3848 is 9.912009384365458e-20
# Variance captured by component 3849 is 9.624262559595162e-20
# Variance captured by component 3850 is 9.624262559595162e-20
# Variance captured by component 3851 is 9.609696839398529e-20
# Variance captured by component 3852 is 9.609696839398529e-20
# Variance captured by component 3853 is 9.541190385067969e-20
# Variance captured by component 3854 is 9.541190385067969e-20
# Variance captured by component 3855 is 9.337245050419378e-20
# Variance captured by component 3856 is 9.337245050419378e-20
# Variance captured by component 3857 is 9.298890113994214e-20
# Variance captured by component 3858 is 9.298890113994214e-20
# Variance captured by component 3859 is 9.291872576402546e-20
# Variance captured by component 3860 is 9.291872576402546e-20
# Variance captured by component 3861 is 9.175862620331235e-20
# Variance captured by component 3862 is 9.175862620331235e-20
# Variance captured by component 3863 is 9.162659968319278e-20
# Variance captured by component 3864 is 9.162659968319278e-20
# Variance captured by component 3865 is 9.073172151970581e-20
# Variance captured by component 3866 is 9.073172151970581e-20
# Variance captured by component 3867 is 9.063035179663025e-20
# Variance captured by component 3868 is 9.063035179663025e-20
# Variance captured by component 3869 is 9.015572917155626e-20
# Variance captured by component 3870 is 8.997853919337251e-20
# Variance captured by component 3871 is 8.997853919337251e-20
# Variance captured by component 3872 is 8.969019029013493e-20
# Variance captured by component 3873 is 8.969019029013493e-20
# Variance captured by component 3874 is 8.959598425721111e-20
# Variance captured by component 3875 is 8.959598425721111e-20
# Variance captured by component 3876 is 8.714367418592309e-20
# Variance captured by component 3877 is 8.714367418592309e-20
# Variance captured by component 3878 is 8.703174391774326e-20
# Variance captured by component 3879 is 8.703174391774326e-20
# Variance captured by component 3880 is 8.639849749659377e-20
# Variance captured by component 3881 is 8.639849749659377e-20
# Variance captured by component 3882 is 8.50061881364347e-20
# Variance captured by component 3883 is 8.50061881364347e-20
# Variance captured by component 3884 is 8.461992137938327e-20
# Variance captured by component 3885 is 8.461992137938327e-20
# Variance captured by component 3886 is 8.391158069972863e-20
# Variance captured by component 3887 is 8.391158069972863e-20
# Variance captured by component 3888 is 8.383830138557238e-20
# Variance captured by component 3889 is 8.383830138557238e-20
# Variance captured by component 3890 is 8.341116995365681e-20
# Variance captured by component 3891 is 8.308355219629826e-20
# Variance captured by component 3892 is 8.308355219629826e-20
# Variance captured by component 3893 is 8.254542446253028e-20
# Variance captured by component 3894 is 8.254542446253028e-20
# Variance captured by component 3895 is 7.526148808199613e-20
# Variance captured by component 3896 is 7.511645396823987e-20
# Variance captured by component 3897 is 7.511645396823987e-20
# Variance captured by component 3898 is 7.488732163242355e-20
# Variance captured by component 3899 is 7.488732163242355e-20
# Variance captured by component 3900 is 7.405255757402384e-20
# Variance captured by component 3901 is 7.405255757402384e-20
# Variance captured by component 3902 is 7.372247801629302e-20
# Variance captured by component 3903 is 7.372247801629302e-20
# Variance captured by component 3904 is 7.33108542322296e-20
# Variance captured by component 3905 is 7.33108542322296e-20
# Variance captured by component 3906 is 7.30233437660905e-20
# Variance captured by component 3907 is 7.30233437660905e-20
# Variance captured by component 3908 is 7.236473855772274e-20
# Variance captured by component 3909 is 7.236473855772274e-20
# Variance captured by component 3910 is 7.190851128874343e-20
# Variance captured by component 3911 is 7.190851128874343e-20
# Variance captured by component 3912 is 7.168334546436001e-20
# Variance captured by component 3913 is 7.168334546436001e-20
# Variance captured by component 3914 is 7.121048817742226e-20
# Variance captured by component 3915 is 7.121048817742226e-20
# Variance captured by component 3916 is 7.036334557960958e-20
# Variance captured by component 3917 is 7.036334557960958e-20
# Variance captured by component 3918 is 7.019529023071061e-20
# Variance captured by component 3919 is 7.019529023071061e-20
# Variance captured by component 3920 is 7.01474705563321e-20
# Variance captured by component 3921 is 7.01474705563321e-20
# Variance captured by component 3922 is 6.841102400573031e-20
# Variance captured by component 3923 is 6.841102400573031e-20
# Variance captured by component 3924 is 6.759468593618409e-20
# Variance captured by component 3925 is 6.759468593618409e-20
# Variance captured by component 3926 is 6.749171980287701e-20
# Variance captured by component 3927 is 6.749171980287701e-20
# Variance captured by component 3928 is 6.706319851877596e-20
# Variance captured by component 3929 is 6.706319851877596e-20
# Variance captured by component 3930 is 6.524034279481774e-20
# Variance captured by component 3931 is 6.524034279481774e-20
# Variance captured by component 3932 is 6.483680282532751e-20
# Variance captured by component 3933 is 6.483680282532751e-20
# Variance captured by component 3934 is 6.47430233980396e-20
# Variance captured by component 3935 is 6.47430233980396e-20
# Variance captured by component 3936 is 6.417893367055286e-20
# Variance captured by component 3937 is 6.417893367055286e-20
# Variance captured by component 3938 is 6.297999883847675e-20
# Variance captured by component 3939 is 6.297999883847675e-20
# Variance captured by component 3940 is 5.9531450208981e-20
# Variance captured by component 3941 is 5.9531450208981e-20
# Variance captured by component 3942 is 5.709050417998735e-20
# Variance captured by component 3943 is 5.709050417998735e-20
# Variance captured by component 3944 is 5.698303486993967e-20
# Variance captured by component 3945 is 5.698303486993967e-20
# Variance captured by component 3946 is 5.350325107689599e-20
# Variance captured by component 3947 is 5.350325107689599e-20
# Variance captured by component 3948 is 5.2721853842044646e-20
# Variance captured by component 3949 is 5.2721853842044646e-20
# Variance captured by component 3950 is 5.2569287073736556e-20
# Variance captured by component 3951 is 5.2569287073736556e-20
# Variance captured by component 3952 is 5.240280167877256e-20
# Variance captured by component 3953 is 5.240280167877256e-20
# Variance captured by component 3954 is 5.236601067870009e-20
# Variance captured by component 3955 is 5.236601067870009e-20
# Variance captured by component 3956 is 5.2001716419128524e-20
# Variance captured by component 3957 is 5.2001716419128524e-20
# Variance captured by component 3958 is 5.150724693867188e-20
# Variance captured by component 3959 is 5.150724693867188e-20
# Variance captured by component 3960 is 5.143701830228422e-20
# Variance captured by component 3961 is 5.143701830228422e-20
# Variance captured by component 3962 is 5.005214395792222e-20
# Variance captured by component 3963 is 4.845266244781946e-20
# Variance captured by component 3964 is 4.845266244781946e-20
# Variance captured by component 3965 is 4.8221797933447637e-20
# Variance captured by component 3966 is 4.8221797933447637e-20
# Variance captured by component 3967 is 4.79385362934937e-20
# Variance captured by component 3968 is 4.79385362934937e-20
# Variance captured by component 3969 is 4.769003403890981e-20
# Variance captured by component 3970 is 4.769003403890981e-20
# Variance captured by component 3971 is 4.5184230761556746e-20
# Variance captured by component 3972 is 4.5184230761556746e-20
# Variance captured by component 3973 is 4.3878626203926644e-20
# Variance captured by component 3974 is 4.3878626203926644e-20
# Variance captured by component 3975 is 4.3512045606795876e-20
# Variance captured by component 3976 is 4.3512045606795876e-20
# Variance captured by component 3977 is 4.31457013981107e-20
# Variance captured by component 3978 is 4.31457013981107e-20
# Variance captured by component 3979 is 4.2672382477961495e-20
# Variance captured by component 3980 is 4.2672382477961495e-20
# Variance captured by component 3981 is 4.175303781984366e-20
# Variance captured by component 3982 is 4.175303781984366e-20
# Variance captured by component 3983 is 4.1453644076948145e-20
# Variance captured by component 3984 is 4.1453644076948145e-20
# Variance captured by component 3985 is 4.0526477014198887e-20
# Variance captured by component 3986 is 4.0526477014198887e-20
# Variance captured by component 3987 is 3.972417988917429e-20
# Variance captured by component 3988 is 3.972417988917429e-20
# Variance captured by component 3989 is 3.9702369547849533e-20
# Variance captured by component 3990 is 3.9702369547849533e-20
# Variance captured by component 3991 is 3.9595189048231735e-20
# Variance captured by component 3992 is 3.9595189048231735e-20
# Variance captured by component 3993 is 3.8869650527502917e-20
# Variance captured by component 3994 is 3.8869650527502917e-20
# Variance captured by component 3995 is 3.886797805384537e-20
# Variance captured by component 3996 is 3.886797805384537e-20
# Variance captured by component 3997 is 3.792204036323185e-20
# Variance captured by component 3998 is 3.792204036323185e-20
# Variance captured by component 3999 is 3.71162047271619e-20
# Variance captured by component 4000 is 3.71162047271619e-20
# Variance captured by component 4001 is 3.5239889655822685e-20
# Variance captured by component 4002 is 3.5239889655822685e-20
# Variance captured by component 4003 is 3.502916291761901e-20
# Variance captured by component 4004 is 3.502916291761901e-20
# Variance captured by component 4005 is 3.3683955161933273e-20
# Variance captured by component 4006 is 3.3683955161933273e-20
# Variance captured by component 4007 is 3.2035358388312604e-20
# Variance captured by component 4008 is 3.2035358388312604e-20
# Variance captured by component 4009 is 3.2008503512423626e-20
# Variance captured by component 4010 is 3.2008503512423626e-20
# Variance captured by component 4011 is 3.1547748576472905e-20
# Variance captured by component 4012 is 3.1547748576472905e-20
# Variance captured by component 4013 is 2.999064991416385e-20
# Variance captured by component 4014 is 2.999064991416385e-20
# Variance captured by component 4015 is 2.9736742203214797e-20
# Variance captured by component 4016 is 2.9736742203214797e-20
# Variance captured by component 4017 is 2.686916859535986e-20
# Variance captured by component 4018 is 2.686916859535986e-20
# Variance captured by component 4019 is 2.6483847942315373e-20
# Variance captured by component 4020 is 2.6483847942315373e-20
# Variance captured by component 4021 is 2.6266811152473784e-20
# Variance captured by component 4022 is 2.6266811152473784e-20
# Variance captured by component 4023 is 2.6214956276227725e-20
# Variance captured by component 4024 is 2.6214956276227725e-20
# Variance captured by component 4025 is 2.5917704186939766e-20
# Variance captured by component 4026 is 2.5917704186939766e-20
# Variance captured by component 4027 is 2.5857300490178862e-20
# Variance captured by component 4028 is 2.5857300490178862e-20
# Variance captured by component 4029 is 2.546830547382713e-20
# Variance captured by component 4030 is 2.546830547382713e-20
# Variance captured by component 4031 is 2.5466416733220002e-20
# Variance captured by component 4032 is 2.5466416733220002e-20
# Variance captured by component 4033 is 2.5242630822565198e-20
# Variance captured by component 4034 is 2.5242630822565198e-20
# Variance captured by component 4035 is 2.42224675178019e-20
# Variance captured by component 4036 is 2.42224675178019e-20
# Variance captured by component 4037 is 2.384208327095023e-20
# Variance captured by component 4038 is 2.384208327095023e-20
# Variance captured by component 4039 is 2.3673655121353017e-20
# Variance captured by component 4040 is 2.3673655121353017e-20
# Variance captured by component 4041 is 2.3474134417564878e-20
# Variance captured by component 4042 is 2.3474134417564878e-20
# Variance captured by component 4043 is 2.3427601262160844e-20
# Variance captured by component 4044 is 2.3427601262160844e-20
# Variance captured by component 4045 is 2.230401620383562e-20
# Variance captured by component 4046 is 2.230401620383562e-20
# Variance captured by component 4047 is 2.0877242579369714e-20
# Variance captured by component 4048 is 2.0877242579369714e-20
# Variance captured by component 4049 is 1.9774433765648516e-20
# Variance captured by component 4050 is 1.9774433765648516e-20
# Variance captured by component 4051 is 1.9602178648936514e-20
# Variance captured by component 4052 is 1.9602178648936514e-20
# Variance captured by component 4053 is 1.917611866345438e-20
# Variance captured by component 4054 is 1.917611866345438e-20
# Variance captured by component 4055 is 1.8743389331662654e-20
# Variance captured by component 4056 is 1.8743389331662654e-20
# Variance captured by component 4057 is 1.7804765049292912e-20
# Variance captured by component 4058 is 1.7804765049292912e-20
# Variance captured by component 4059 is 1.675756722458136e-20
# Variance captured by component 4060 is 1.4769846320393983e-20
# Variance captured by component 4061 is 1.4769846320393983e-20
# Variance captured by component 4062 is 1.4471826164917857e-20
# Variance captured by component 4063 is 1.4471826164917857e-20
# Variance captured by component 4064 is 1.4426549632977813e-20
# Variance captured by component 4065 is 1.4426549632977813e-20
# Variance captured by component 4066 is 1.3264757909998554e-20
# Variance captured by component 4067 is 1.3264757909998554e-20
# Variance captured by component 4068 is 1.182471249701845e-20
# Variance captured by component 4069 is 1.182471249701845e-20
# Variance captured by component 4070 is 9.663362409271834e-21
# Variance captured by component 4071 is 9.663362409271834e-21
# Variance captured by component 4072 is 7.958649425326592e-21
# Variance captured by component 4073 is 7.958649425326592e-21
# Variance captured by component 4074 is 7.92307063318534e-21
# Variance captured by component 4075 is 7.92307063318534e-21
# Variance captured by component 4076 is 7.031200526486941e-21
# Variance captured by component 4077 is 7.031200526486941e-21
# Variance captured by component 4078 is 6.91934682162692e-21
# Variance captured by component 4079 is 6.91934682162692e-21
# Variance captured by component 4080 is 6.779834332662412e-21
# Variance captured by component 4081 is 6.779834332662412e-21
# Variance captured by component 4082 is 5.435253652563315e-21
# Variance captured by component 4083 is 5.435253652563315e-21
# Variance captured by component 4084 is 4.238776534072095e-21
# Variance captured by component 4085 is 4.238776534072095e-21
# Variance captured by component 4086 is 4.1383647514548095e-21
# Variance captured by component 4087 is 4.1383647514548095e-21
# Variance captured by component 4088 is 3.965359722585184e-21
# Variance captured by component 4089 is 3.965359722585184e-21
# Variance captured by component 4090 is 3.079449087389666e-21
# Variance captured by component 4091 is 2.7346221487241744e-21
# Variance captured by component 4092 is 2.7346221487241744e-21
# Variance captured by component 4093 is 1.5599491666043581e-21
# Variance captured by component 4094 is 1.5599491666043581e-21
# Variance captured by component 4095 is 1.1247716697488066e-21
# Variance captured by component 4096 is 1.1247716697488066e-21
# Accuracy of the Nearest Neighbor model is:  95.0 %
# Accuracy of the Naive Bayes model is:  75.0 %

# %%
# plot the variance vs number of components
pca.plot_variance()

# %% [markdown]
# 5. <b>Fisherfaces- Face classification using LDA (40 classes)
#
#     a) Use the following “face.csv” file to classify the faces of 40 different people using LDA. \
#     b) Do not use the in-built function for implementing LDA. \
#     c) Use appropriate classifier taught in class (any classification algorithm taught in class like Bayes classifier, minimum distance classifier, and so on ) \
#     d) Refer to the following link for a description of the dataset: </b>
#     [link](https://towardsdatascience.com/eigenfaces-face-classification-in-python-7b8d2af3d3e)

# %%
# perform LDA on the training data using the LDA class defined above

lda = LDA_inbuilt()

lda.fit(X, y)

# transform the training data
X_train_lda = lda.transform(X_train)

# transform the testing data
X_test_lda = lda.transform(X_test)

# classify the testing data using Nearest Neighbor Classifier and print the accuracy
knn = KNeighborsClassifier(n_neighbors = 1)

knn.fit(X_train_lda, y_train)

pred_mindist_lda = knn.predict(X_test_lda)

print("Accuracy of the Nearest Neighbor model is: ", accuracy_score(y_test, pred_mindist_lda)*100, "%")

# classify the testing data using Naive Bayes Classifier and print the accuracy
gnb = GaussianNB()

gnb.fit(X_train_lda, y_train)

pred_nb_lda = gnb.predict(X_test_lda)

print("Accuracy of the Naive Bayes model is: ", accuracy_score(y_test, pred_nb_lda)*100, "%")
# Out:
# Accuracy of the Nearest Neighbor model is:  100.0 %
# Accuracy of the Naive Bayes model is:  100.0 %
